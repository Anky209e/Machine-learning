# %%
import os

DATA_DIR = 'paint'
print(os.listdir(DATA_DIR))
# Out:
# ['images']

# %%
from torch.utils.data import DataLoader
from torchvision.datasets import ImageFolder
import torchvision.transforms as T

# %%
image_size = 256
batch_size = 50
stats = (0.5, 0.5, 0.5), (0.5, 0.5, 0.5)

# %%
train_ds = ImageFolder(DATA_DIR, transform=T.Compose([
    T.Resize(image_size),
    T.CenterCrop(image_size),
    T.ToTensor(),
    T.Normalize(*stats)]))

train_dl = DataLoader(train_ds, batch_size, shuffle=True, num_workers=3, pin_memory=True)

# %%
import torch
from torchvision.utils import make_grid
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def denorm(img_tensors):
    return img_tensors * stats[1][0] + stats[0][0]

# %%
def show_images(images, nmax=64):
    fig, ax = plt.subplots(figsize=(8, 8))
    ax.set_xticks([]); ax.set_yticks([])
    ax.imshow(make_grid(denorm(images.detach()[:nmax]), nrow=8).permute(1, 2, 0))

def show_batch(dl, nmax=64):
    for images, _ in dl:
        show_images(images, nmax)
        break

# %%
show_batch(train_dl)

# %%
def get_default_device():
    """Pick GPU if available, else CPU"""
    if torch.cuda.is_available():
        return torch.device('cuda')
    else:
        return torch.device('cpu')
    
def to_device(data, device):
    """Move tensor(s) to chosen device"""
    if isinstance(data, (list,tuple)):
        return [to_device(x, device) for x in data]
    return data.to(device, non_blocking=True)

class DeviceDataLoader():
    """Wrap a dataloader to move data to a device"""
    def __init__(self, dl, device):
        self.dl = dl
        self.device = device
        
    def __iter__(self):
        """Yield a batch of data after moving it to device"""
        for b in self.dl: 
            yield to_device(b, self.device)

    def __len__(self):
        """Number of batches"""
        return len(self.dl)

# %%
device = get_default_device()
device
# Out:
# device(type='cuda')

# %%
train_dl = DeviceDataLoader(train_dl, device)

# %%
import torch.nn as nn

# %%
discriminator= nn.Sequential(
    # Input is 3 x 256 x 256
    nn.Conv2d(3, 16, kernel_size=4, stride=2, padding=1, bias=False),
    nn.BatchNorm2d(16),
    nn.LeakyReLU(0.3, inplace=True),
    # Layer Output: 16 x 128 x 128
    
    nn.Conv2d(16, 32, kernel_size=4, stride=2, padding=1, bias=False),
    nn.BatchNorm2d(32),
    nn.LeakyReLU(0.3, inplace=True),
    # Layer Output: 32 x 64 x 64
    
    nn.Conv2d(32, 64, kernel_size=4, stride=2, padding=1, bias=False),
    nn.BatchNorm2d(64),
    nn.LeakyReLU(0.3, inplace=True),
    # Layer Output: 64 x 32 x 32
    
    nn.Conv2d(64, 128, kernel_size=4, stride=2, padding=1, bias=False),
    nn.BatchNorm2d(128),
    nn.LeakyReLU(0.3, inplace=True),
    # Layer Output: 128 x 16 x 16
    
    nn.Conv2d(128, 256, kernel_size=4, stride=2, padding=1, bias=False),
    nn.BatchNorm2d(256),
    nn.LeakyReLU(0.3, inplace=True),
    # Layer Output: 256 x 8 x 8
    
    nn.Conv2d(256, 512, kernel_size=4, stride=2, padding=1, bias=False),
    nn.BatchNorm2d(512),
    nn.LeakyReLU(0.3, inplace=True),
    # Layer Output: 512 x 4 x 4
    
    
    nn.Conv2d(512, 1, kernel_size=4, stride=1, padding=0, bias=False),
    nn.Flatten(),
    nn.Sigmoid()
)

# %%
discriminator = to_device(discriminator, device)

# %%
discriminator
# Out:
# Sequential(
#   (0): Conv2d(3, 16, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): LeakyReLU(negative_slope=0.3, inplace=True)
#   (3): Conv2d(16, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (4): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (5): LeakyReLU(negative_slope=0.3, inplace=True)
#   (6): Conv2d(32, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (7): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (8): LeakyReLU(negative_slope=0.3, inplace=True)
#   (9): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (10): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (11): LeakyReLU(negative_slope=0.3, inplace=True)
#   (12): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (13): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (14): LeakyReLU(negative_slope=0.3, inplace=True)
#   (15): Conv2d(256, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (16): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (17): LeakyReLU(negative_slope=0.3, inplace=True)
#   (18): Conv2d(512, 1, kernel_size=(4, 4), stride=(1, 1), bias=False)
#   (19): Flatten(start_dim=1, end_dim=-1)
#   (20): Sigmoid()
# )

# %%
latent_size = 128

# %%
generator = nn.Sequential(
    #  seed_size x 1 x 1
    nn.ConvTranspose2d(latent_size, 512, kernel_size=4, padding=0, stride=1, bias=False),
    nn.BatchNorm2d(512),
    nn.ReLU(True),
    # 512 x 4 x 4
    
    nn.ConvTranspose2d(512, 256, kernel_size=4, padding=1, stride=2, bias=False),
    nn.BatchNorm2d(256),
    nn.ReLU(True),
    # 256 x 8 x 8
    
    nn.ConvTranspose2d(256, 128, kernel_size=4, padding=1, stride=2, bias=False),
    nn.BatchNorm2d(128),
    nn.ReLU(True),
    #  128 x 16 x 16
    
    nn.ConvTranspose2d(128, 64, kernel_size=4, padding=1, stride=2, bias=False),
    nn.BatchNorm2d(64),
    nn.ReLU(True),
    #  64 x 32 x 32
    
    nn.ConvTranspose2d(64, 32, kernel_size=4, padding=1, stride=2, bias=False),
    nn.BatchNorm2d(32),
    nn.ReLU(True),
    #  32 x 64 x 64
    
    nn.ConvTranspose2d(32, 16, kernel_size=4, padding=1, stride=2, bias=False),
    nn.BatchNorm2d(16),
    nn.ReLU(True),
    #  16 x 128 x 128
    
    nn.ConvTranspose2d(16, 3, kernel_size=4, padding=1, stride=2, bias=False),
    nn.Tanh()
    #  3 x 256 x 256
)

# %%
xb = torch.randn(batch_size, 128, 1, 1) # random latent tensors
fake_images = generator(xb)
print(fake_images.shape)
show_images(fake_images)
# Out:
# torch.Size([50, 3, 256, 256])

# %%
generator = to_device(generator, device)

# %%
def train_discriminator(real_images, opt_d):
    # Clear discriminator gradients
    opt_d.zero_grad()

    # Pass real images through discriminator
    real_preds = discriminator(real_images)
    real_targets = torch.ones(real_images.size(0), 1, device=device)
    real_loss = F.binary_cross_entropy(real_preds, real_targets)
    real_score = torch.mean(real_preds).item()
    
    # Generate fake images
    latent = torch.randn(batch_size, latent_size, 1, 1, device=device)
    fake_images = generator(latent)

    # Pass fake images through discriminator
    fake_targets = torch.zeros(fake_images.size(0), 1, device=device)
    fake_preds = discriminator(fake_images)
    fake_loss = F.binary_cross_entropy(fake_preds, fake_targets)
    fake_score = torch.mean(fake_preds).item()

    # Update discriminator weights
    loss = real_loss + fake_loss
    loss.backward()
    opt_d.step()
    return loss.item(), real_score, fake_score

# %%
def train_generator(opt_g):
    # Clear generator gradients
    opt_g.zero_grad()
    
    # Generate fake images
    latent = torch.randn(batch_size, latent_size, 1, 1, device=device)
    fake_images = generator(latent)
    
    # Try to fool the discriminator
    preds = discriminator(fake_images)
    targets = torch.ones(batch_size, 1, device=device)
    loss = F.binary_cross_entropy(preds, targets)
    
    # Update generator weights
    loss.backward()
    opt_g.step()
    
    return loss.item()

# %%
from torchvision.utils import save_image

# %%
sample_dir = 'paint_gen_256'
os.makedirs(sample_dir, exist_ok=True)

# %%
def save_samples(index, latent_tensors, show=True):
    fake_images = generator(latent_tensors)
    fake_fname = 'car-img-{0:0=4d}.png'.format(index)
    save_image(denorm(fake_images), os.path.join(sample_dir, fake_fname), nrow=3)
    print('Saving', fake_fname)
    if show:
        fig, ax = plt.subplots(figsize=(8, 8))
        ax.set_xticks([]); ax.set_yticks([])
        ax.imshow(make_grid(fake_images.cpu().detach(), nrow=3).permute(1, 2, 0))

# %%
fixed_latent = torch.randn(9, latent_size, 1, 1, device=device)

# %%
save_samples(0, fixed_latent)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Saving car-img-0000.png

# %%
import torch.nn.functional as F

# %%
def fit(epochs, lr, start_idx=1):
    torch.cuda.empty_cache()
    
    # Losses & scores
    losses_g = []
    losses_d = []
    real_scores = []
    fake_scores = []
    
    # Create optimizers
    opt_d = torch.optim.Adam(discriminator.parameters(), lr=lr, betas=(0.5, 0.999))
    opt_g = torch.optim.Adam(generator.parameters(), lr=lr, betas=(0.5, 0.999))
    
    for epoch in range(epochs):
        for real_images, _ in (train_dl):
            # Train discriminator
            loss_d, real_score, fake_score = train_discriminator(real_images, opt_d)
            # Train generator
            loss_g = train_generator(opt_g)
            if loss_d < loss_g:
                loss_d, real_score, fake_score = train_discriminator(real_images, opt_d)

            
        
        losses_g.append(loss_g)
        losses_d.append(loss_d)
        real_scores.append(real_score)
        fake_scores.append(fake_score)
        
        
        print("Epoch [{}/{}], loss_g: {:.4f}, loss_d: {:.4f}, real_score: {:.4f}, fake_score: {:.4f}".format(
            epoch+1, epochs, loss_g, loss_d, real_score, fake_score))
    
        
        save_samples(epoch+start_idx, fixed_latent, show=False)
    
    return losses_g, losses_d, real_scores, fake_scores

# %%
lr = 0.0023
epochs = 90

# %%
history = fit(epochs, lr,start_idx=34)
# Out:
# Epoch [1/90], loss_g: 12.2249, loss_d: 0.1051, real_score: 0.9076, fake_score: 0.0006
# Saving car-img-0034.png
# Epoch [2/90], loss_g: 4.3098, loss_d: 1.2221, real_score: 0.9699, fake_score: 0.6311
# Saving car-img-0035.png
# Epoch [3/90], loss_g: 5.1342, loss_d: 0.4538, real_score: 0.9464, fake_score: 0.2729
# Saving car-img-0036.png
# Epoch [4/90], loss_g: 7.3420, loss_d: 0.0813, real_score: 0.9404, fake_score: 0.0159
# Saving car-img-0037.png
# Epoch [5/90], loss_g: 4.2552, loss_d: 0.1321, real_score: 0.9887, fake_score: 0.1091
# Saving car-img-0038.png
# Epoch [6/90], loss_g: 7.9176, loss_d: 0.2238, real_score: 0.9702, fake_score: 0.1429
# Saving car-img-0039.png
# Epoch [7/90], loss_g: 6.5288, loss_d: 0.0243, real_score: 0.9855, fake_score: 0.0092
# Saving car-img-0040.png
# Epoch [8/90], loss_g: 5.6748, loss_d: 0.1823, real_score: 0.9983, fake_score: 0.1413
# Saving car-img-0041.png
# Epoch [9/90], loss_g: 5.2267, loss_d: 0.1100, real_score: 0.9729, fake_score: 0.0716
# Saving car-img-0042.png
# Epoch [10/90], loss_g: 9.5800, loss_d: 0.0550, real_score: 0.9492, fake_score: 0.0006
# Saving car-img-0043.png
# Epoch [11/90], loss_g: 5.7825, loss_d: 0.1163, real_score: 0.9844, fake_score: 0.0870
# Saving car-img-0044.png
# Epoch [12/90], loss_g: 5.8639, loss_d: 0.2240, real_score: 0.9707, fake_score: 0.1626
# Saving car-img-0045.png
# Epoch [13/90], loss_g: 7.0037, loss_d: 0.0933, real_score: 0.9825, fake_score: 0.0704
# Saving car-img-0046.png
# Epoch [14/90], loss_g: 6.2029, loss_d: 0.0416, real_score: 0.9975, fake_score: 0.0376
# Saving car-img-0047.png
# Epoch [15/90], loss_g: 5.8037, loss_d: 0.3782, real_score: 0.9866, fake_score: 0.2200
# Saving car-img-0048.png
# Epoch [16/90], loss_g: 10.8715, loss_d: 0.1583, real_score: 0.9160, fake_score: 0.0415
# Saving car-img-0049.png
# Epoch [17/90], loss_g: 8.1284, loss_d: 0.1627, real_score: 0.9330, fake_score: 0.0653
# Saving car-img-0050.png
# Epoch [18/90], loss_g: 7.5445, loss_d: 0.0581, real_score: 0.9468, fake_score: 0.0016
# Saving car-img-0051.png
# Epoch [19/90], loss_g: 5.2747, loss_d: 0.0011, real_score: 0.9996, fake_score: 0.0007
# Saving car-img-0052.png
# Epoch [20/90], loss_g: 5.0636, loss_d: 0.0992, real_score: 0.9776, fake_score: 0.0664
# Saving car-img-0053.png
# Epoch [21/90], loss_g: 6.2861, loss_d: 0.0130, real_score: 0.9972, fake_score: 0.0099
# Saving car-img-0054.png
# Epoch [22/90], loss_g: 6.3310, loss_d: 0.2400, real_score: 0.9840, fake_score: 0.1814
# Saving car-img-0055.png
# Epoch [23/90], loss_g: 9.9866, loss_d: 0.0682, real_score: 0.9876, fake_score: 0.0491
# Saving car-img-0056.png
# Epoch [24/90], loss_g: 8.1994, loss_d: 0.0275, real_score: 0.9780, fake_score: 0.0035
# Saving car-img-0057.png
# Epoch [25/90], loss_g: 7.1500, loss_d: 0.0148, real_score: 0.9998, fake_score: 0.0141
# Saving car-img-0058.png
# Epoch [26/90], loss_g: 8.1406, loss_d: 0.0225, real_score: 0.9885, fake_score: 0.0104
# Saving car-img-0059.png
# Epoch [27/90], loss_g: 13.7845, loss_d: 0.0974, real_score: 0.9136, fake_score: 0.0001
# Saving car-img-0060.png
# Epoch [28/90], loss_g: 10.0159, loss_d: 0.0073, real_score: 0.9970, fake_score: 0.0041
# Saving car-img-0061.png
# Epoch [29/90], loss_g: 10.8280, loss_d: 0.0654, real_score: 0.9404, fake_score: 0.0004
# Saving car-img-0062.png
# Epoch [30/90], loss_g: 4.4256, loss_d: 0.1440, real_score: 1.0000, fake_score: 0.1144
# Saving car-img-0063.png
# Epoch [31/90], loss_g: 6.5487, loss_d: 0.0277, real_score: 0.9998, fake_score: 0.0261
# Saving car-img-0064.png
# Epoch [32/90], loss_g: 6.6761, loss_d: 0.0827, real_score: 0.9951, fake_score: 0.0685
# Saving car-img-0065.png
# Epoch [33/90], loss_g: 5.2079, loss_d: 0.1701, real_score: 0.9997, fake_score: 0.1001
# Saving car-img-0066.png
# Epoch [34/90], loss_g: 5.2383, loss_d: 0.1958, real_score: 0.9894, fake_score: 0.1224
# Saving car-img-0067.png
# Epoch [35/90], loss_g: 7.3650, loss_d: 0.0200, real_score: 0.9909, fake_score: 0.0106
# Saving car-img-0068.png
# Epoch [36/90], loss_g: 9.4188, loss_d: 0.1312, real_score: 0.9928, fake_score: 0.1041
# Saving car-img-0069.png
# Epoch [37/90], loss_g: 13.4818, loss_d: 0.0077, real_score: 0.9924, fake_score: 0.0000
# Saving car-img-0070.png
# Epoch [38/90], loss_g: 6.8525, loss_d: 0.0204, real_score: 0.9866, fake_score: 0.0065
# Saving car-img-0071.png
# Epoch [39/90], loss_g: 12.1309, loss_d: 0.0173, real_score: 0.9987, fake_score: 0.0150
# Saving car-img-0072.png
# Epoch [40/90], loss_g: 5.9216, loss_d: 0.0694, real_score: 0.9901, fake_score: 0.0526
# Saving car-img-0073.png
# Epoch [41/90], loss_g: 6.4632, loss_d: 0.0815, real_score: 0.9862, fake_score: 0.0617
# Saving car-img-0074.png
# Epoch [42/90], loss_g: 7.9143, loss_d: 0.0004, real_score: 1.0000, fake_score: 0.0004
# Saving car-img-0075.png
# Epoch [43/90], loss_g: 13.4161, loss_d: 0.0044, real_score: 0.9964, fake_score: 0.0008
# Saving car-img-0076.png
# Epoch [44/90], loss_g: 9.3860, loss_d: 0.0190, real_score: 0.9872, fake_score: 0.0058
# Saving car-img-0077.png

# %%
# torch.save(generator.state_dict(), 'G_paint.pth')
# torch.save(discriminator.state_dict(), 'D_paint.pth')

# %%
# import cv2
# import os


# frame = cv2.imread("car_gen1/car-img-0198.png")
# height, width, layers = frame.shape


# #insering frames into video
# video = cv2.VideoWriter("./car_gan.avi", 0,20, (width, height)) 
# files = os.listdir("car_gen1")
# files.sort()
# for i in files: 
#    video.write(cv2.imread("car_gen1/"+i)) 
#    print(i)
