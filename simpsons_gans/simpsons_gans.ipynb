# %%
import os

DATA_DIR = 'simp_gans_data'
print(os.listdir(DATA_DIR))
# Out:
# ['images']

# %%
from torch.utils.data import DataLoader
from torchvision.datasets import ImageFolder
import torchvision.transforms as T

# %%
image_size = 64
batch_size = 128
stats = (0.5, 0.5, 0.5), (0.5, 0.5, 0.5)

# %%
train_ds = ImageFolder(DATA_DIR, transform=T.Compose([
    T.Resize(image_size),
    T.CenterCrop(image_size),
    T.ToTensor(),
    T.Normalize(*stats)]))

train_dl = DataLoader(train_ds, batch_size, shuffle=True, num_workers=3, pin_memory=True)

# %%
import torch
from torchvision.utils import make_grid
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def denorm(img_tensors):
    return img_tensors * stats[1][0] + stats[0][0]

# %%
def show_images(images, nmax=64):
    fig, ax = plt.subplots(figsize=(8, 8))
    ax.set_xticks([]); ax.set_yticks([])
    ax.imshow(make_grid(denorm(images.detach()[:nmax]), nrow=8).permute(1, 2, 0))

def show_batch(dl, nmax=64):
    for images, _ in dl:
        show_images(images, nmax)
        break

# %%
show_batch(train_dl)

# %%
def get_default_device():
    """Pick GPU if available, else CPU"""
    if torch.cuda.is_available():
        return torch.device('cuda')
    else:
        return torch.device('cpu')
    
def to_device(data, device):
    """Move tensor(s) to chosen device"""
    if isinstance(data, (list,tuple)):
        return [to_device(x, device) for x in data]
    return data.to(device, non_blocking=True)

class DeviceDataLoader():
    """Wrap a dataloader to move data to a device"""
    def __init__(self, dl, device):
        self.dl = dl
        self.device = device
        
    def __iter__(self):
        """Yield a batch of data after moving it to device"""
        for b in self.dl: 
            yield to_device(b, self.device)

    def __len__(self):
        """Number of batches"""
        return len(self.dl)

# %%
device = get_default_device()
device
# Out:
# device(type='cuda')

# %%
train_dl = DeviceDataLoader(train_dl, device)

# %%
import torch.nn as nn

# %%
discriminator = nn.Sequential(
    # in: 3 x 64 x 64

    nn.Conv2d(3, 64, kernel_size=4, stride=2, padding=1, bias=False),
    nn.BatchNorm2d(64),
    nn.LeakyReLU(0.2, inplace=True),
    # out: 64 x 32 x 32

    nn.Conv2d(64, 128, kernel_size=4, stride=2, padding=1, bias=False),
    nn.BatchNorm2d(128),
    nn.LeakyReLU(0.2, inplace=True),
    # out: 128 x 16 x 16

    nn.Conv2d(128, 256, kernel_size=4, stride=2, padding=1, bias=False),
    nn.BatchNorm2d(256),
    nn.LeakyReLU(0.2, inplace=True),
    # out: 256 x 8 x 8

    nn.Conv2d(256, 512, kernel_size=4, stride=2, padding=1, bias=False),
    nn.BatchNorm2d(512),
    nn.LeakyReLU(0.2, inplace=True),
    # out: 512 x 4 x 4

    nn.Conv2d(512, 1, kernel_size=4, stride=1, padding=0, bias=False),
    # out: 1 x 1 x 1

    nn.Flatten(),
    nn.Sigmoid())

# %%
discriminator = to_device(discriminator, device)

# %%
discriminator
# Out:
# Sequential(
#   (0): Conv2d(3, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): LeakyReLU(negative_slope=0.2, inplace=True)
#   (3): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (5): LeakyReLU(negative_slope=0.2, inplace=True)
#   (6): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (7): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (8): LeakyReLU(negative_slope=0.2, inplace=True)
#   (9): Conv2d(256, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (10): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (11): LeakyReLU(negative_slope=0.2, inplace=True)
#   (12): Conv2d(512, 1, kernel_size=(4, 4), stride=(1, 1), bias=False)
#   (13): Flatten(start_dim=1, end_dim=-1)
#   (14): Sigmoid()
# )

# %%
latent_size = 128

# %%
generator = nn.Sequential(
    # in: latent_size x 1 x 1

    nn.ConvTranspose2d(latent_size, 512, kernel_size=4, stride=1, padding=0, bias=False),
    nn.BatchNorm2d(512),
    nn.ReLU(True),
    # out: 512 x 4 x 4

    nn.ConvTranspose2d(512, 256, kernel_size=4, stride=2, padding=1, bias=False),
    nn.BatchNorm2d(256),
    nn.ReLU(True),
    # out: 256 x 8 x 8

    nn.ConvTranspose2d(256, 128, kernel_size=4, stride=2, padding=1, bias=False),
    nn.BatchNorm2d(128),
    nn.ReLU(True),
    # out: 128 x 16 x 16

    nn.ConvTranspose2d(128, 64, kernel_size=4, stride=2, padding=1, bias=False),
    nn.BatchNorm2d(64),
    nn.ReLU(True),
    # out: 64 x 32 x 32

    nn.ConvTranspose2d(64, 3, kernel_size=4, stride=2, padding=1, bias=False),
    nn.Tanh()
    # out: 3 x 64 x 64
)

# %%
xb = torch.randn(batch_size, latent_size, 1, 1) # random latent tensors
fake_images = generator(xb)
print(fake_images.shape)
show_images(fake_images)
# Out:
# torch.Size([128, 3, 64, 64])

# %%
generator = to_device(generator, device)

# %%
def train_discriminator(real_images, opt_d):
    # Clear discriminator gradients
    opt_d.zero_grad()

    # Pass real images through discriminator
    real_preds = discriminator(real_images)
    real_targets = torch.ones(real_images.size(0), 1, device=device)
    real_loss = F.binary_cross_entropy(real_preds, real_targets)
    real_score = torch.mean(real_preds).item()
    
    # Generate fake images
    latent = torch.randn(batch_size, latent_size, 1, 1, device=device)
    fake_images = generator(latent)

    # Pass fake images through discriminator
    fake_targets = torch.zeros(fake_images.size(0), 1, device=device)
    fake_preds = discriminator(fake_images)
    fake_loss = F.binary_cross_entropy(fake_preds, fake_targets)
    fake_score = torch.mean(fake_preds).item()

    # Update discriminator weights
    loss = real_loss + fake_loss
    loss.backward()
    opt_d.step()
    return loss.item(), real_score, fake_score

# %%
def train_generator(opt_g):
    # Clear generator gradients
    opt_g.zero_grad()
    
    # Generate fake images
    latent = torch.randn(batch_size, latent_size, 1, 1, device=device)
    fake_images = generator(latent)
    
    # Try to fool the discriminator
    preds = discriminator(fake_images)
    targets = torch.ones(batch_size, 1, device=device)
    loss = F.binary_cross_entropy(preds, targets)
    
    # Update generator weights
    loss.backward()
    opt_g.step()
    
    return loss.item()

# %%
from torchvision.utils import save_image

# %%
sample_dir = 'simp_generation_1'
os.makedirs(sample_dir, exist_ok=True)

# %%
def save_samples(index, latent_tensors, show=True):
    fake_images = generator(latent_tensors)
    fake_fname = 'simp-img-{0:0=4d}.png'.format(index)
    save_image(denorm(fake_images), os.path.join(sample_dir, fake_fname), nrow=8)
    print('Saving', fake_fname)
    if show:
        fig, ax = plt.subplots(figsize=(8, 8))
        ax.set_xticks([]); ax.set_yticks([])
        ax.imshow(make_grid(fake_images.cpu().detach(), nrow=8).permute(1, 2, 0))

# %%
fixed_latent = torch.randn(64, latent_size, 1, 1, device=device)

# %%
save_samples(0, fixed_latent)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Saving simp-img-0000.png

# %%
import torch.nn.functional as F

# %%
def fit(epochs, lr, start_idx=1):
    torch.cuda.empty_cache()
    
    # Losses & scores
    losses_g = []
    losses_d = []
    real_scores = []
    fake_scores = []
    
    # Create optimizers
    opt_d = torch.optim.Adam(discriminator.parameters(), lr=lr, betas=(0.5, 0.999))
    opt_g = torch.optim.Adam(generator.parameters(), lr=lr, betas=(0.5, 0.999))
    
    for epoch in range(epochs):
        for real_images, _ in (train_dl):
            # Train discriminator
            loss_d, real_score, fake_score = train_discriminator(real_images, opt_d)
            # Train generator
            loss_g = train_generator(opt_g)
            
        # Record losses & scores
        losses_g.append(loss_g)
        losses_d.append(loss_d)
        real_scores.append(real_score)
        fake_scores.append(fake_score)
        
        # Log losses & scores (last batch)
        print("Epoch [{}/{}], loss_g: {:.4f}, loss_d: {:.4f}, real_score: {:.4f}, fake_score: {:.4f}".format(
            epoch+1, epochs, loss_g, loss_d, real_score, fake_score))
    
        # Save generated images
        save_samples(epoch+start_idx, fixed_latent, show=False)
    
    return losses_g, losses_d, real_scores, fake_scores

# %%
lr = 0.0002
epochs = 300

# %%
history = fit(epochs, lr,start_idx=1)
# Out:
# Epoch [1/300], loss_g: 6.2040, loss_d: 0.1574, real_score: 0.9033, fake_score: 0.0480
# Saving simp-img-0001.png
# Epoch [2/300], loss_g: 6.2165, loss_d: 0.6644, real_score: 0.9059, fake_score: 0.3993
# Saving simp-img-0002.png
# Epoch [3/300], loss_g: 1.6813, loss_d: 0.5344, real_score: 0.7003, fake_score: 0.1242
# Saving simp-img-0003.png
# Epoch [4/300], loss_g: 1.6257, loss_d: 0.8260, real_score: 0.5791, fake_score: 0.0810
# Saving simp-img-0004.png
# Epoch [5/300], loss_g: 5.5753, loss_d: 0.4825, real_score: 0.8558, fake_score: 0.2483
# Saving simp-img-0005.png
# Epoch [6/300], loss_g: 2.8491, loss_d: 0.5137, real_score: 0.7755, fake_score: 0.2030
# Saving simp-img-0006.png
# Epoch [7/300], loss_g: 0.8112, loss_d: 1.1812, real_score: 0.3844, fake_score: 0.0771
# Saving simp-img-0007.png
# Epoch [8/300], loss_g: 5.6705, loss_d: 1.1274, real_score: 0.9434, fake_score: 0.6046
# Saving simp-img-0008.png
# Epoch [9/300], loss_g: 2.1885, loss_d: 0.4847, real_score: 0.7663, fake_score: 0.1703
# Saving simp-img-0009.png
# Epoch [10/300], loss_g: 4.0718, loss_d: 0.6790, real_score: 0.5442, fake_score: 0.0136
# Saving simp-img-0010.png
# Epoch [11/300], loss_g: 2.4257, loss_d: 0.3320, real_score: 0.9520, fake_score: 0.2320
# Saving simp-img-0011.png
# Epoch [12/300], loss_g: 3.5917, loss_d: 0.4079, real_score: 0.8843, fake_score: 0.2301
# Saving simp-img-0012.png
# Epoch [13/300], loss_g: 3.4657, loss_d: 0.3390, real_score: 0.9324, fake_score: 0.2221
# Saving simp-img-0013.png
# Epoch [14/300], loss_g: 5.3336, loss_d: 0.7973, real_score: 0.9492, fake_score: 0.4778
# Saving simp-img-0014.png
# Epoch [15/300], loss_g: 7.1722, loss_d: 1.1701, real_score: 0.9625, fake_score: 0.6288
# Saving simp-img-0015.png
# Epoch [16/300], loss_g: 4.2398, loss_d: 0.2673, real_score: 0.9411, fake_score: 0.1739
# Saving simp-img-0016.png
# Epoch [17/300], loss_g: 2.8410, loss_d: 4.9395, real_score: 0.0441, fake_score: 0.0001
# Saving simp-img-0017.png
# Epoch [18/300], loss_g: 3.5301, loss_d: 0.1659, real_score: 0.9197, fake_score: 0.0744
# Saving simp-img-0018.png
# Epoch [19/300], loss_g: 3.7073, loss_d: 1.9460, real_score: 0.2115, fake_score: 0.0005
# Saving simp-img-0019.png
# Epoch [20/300], loss_g: 6.9524, loss_d: 1.2869, real_score: 0.9967, fake_score: 0.6320
# Saving simp-img-0020.png
# Epoch [21/300], loss_g: 6.2413, loss_d: 0.3956, real_score: 0.9435, fake_score: 0.2590
# Saving simp-img-0021.png
# Epoch [22/300], loss_g: 2.4618, loss_d: 0.5248, real_score: 0.6472, fake_score: 0.0514
# Saving simp-img-0022.png
# Epoch [23/300], loss_g: 6.3102, loss_d: 0.0357, real_score: 0.9823, fake_score: 0.0173
# Saving simp-img-0023.png
# Epoch [24/300], loss_g: 4.0386, loss_d: 0.3385, real_score: 0.8767, fake_score: 0.1682
# Saving simp-img-0024.png
# Epoch [25/300], loss_g: 3.3371, loss_d: 0.2949, real_score: 0.8154, fake_score: 0.0609
# Saving simp-img-0025.png
# Epoch [26/300], loss_g: 3.3818, loss_d: 0.3696, real_score: 0.8526, fake_score: 0.1631
# Saving simp-img-0026.png
# Epoch [27/300], loss_g: 6.3852, loss_d: 0.1453, real_score: 0.9977, fake_score: 0.1202
# Saving simp-img-0027.png
# Epoch [28/300], loss_g: 17.1569, loss_d: 3.1021, real_score: 0.9998, fake_score: 0.8900
# Saving simp-img-0028.png
# Epoch [29/300], loss_g: 3.0539, loss_d: 0.2957, real_score: 0.8652, fake_score: 0.1250
# Saving simp-img-0029.png
# Epoch [30/300], loss_g: 3.7485, loss_d: 0.2684, real_score: 0.7851, fake_score: 0.0061
# Saving simp-img-0030.png
# Epoch [31/300], loss_g: 4.3255, loss_d: 0.5301, real_score: 0.9405, fake_score: 0.3439
# Saving simp-img-0031.png
# Epoch [32/300], loss_g: 4.6765, loss_d: 5.2548, real_score: 0.0096, fake_score: 0.0000
# Saving simp-img-0032.png
# Epoch [33/300], loss_g: 4.5962, loss_d: 0.1434, real_score: 0.9731, fake_score: 0.1061
# Saving simp-img-0033.png
# Epoch [34/300], loss_g: 5.1279, loss_d: 0.2085, real_score: 0.9558, fake_score: 0.1348
# Saving simp-img-0034.png
# Epoch [35/300], loss_g: 0.6211, loss_d: 0.5298, real_score: 0.6628, fake_score: 0.0696
# Saving simp-img-0035.png
# Epoch [36/300], loss_g: 3.5755, loss_d: 0.1143, real_score: 0.9264, fake_score: 0.0352
# Saving simp-img-0036.png
# Epoch [37/300], loss_g: 4.3787, loss_d: 0.1285, real_score: 0.9614, fake_score: 0.0809
# Saving simp-img-0037.png
# Epoch [38/300], loss_g: 2.5286, loss_d: 0.2471, real_score: 0.8382, fake_score: 0.0533
# Saving simp-img-0038.png
# Epoch [39/300], loss_g: 12.5546, loss_d: 2.2311, real_score: 1.0000, fake_score: 0.8265
# Saving simp-img-0039.png
# Epoch [40/300], loss_g: 3.1950, loss_d: 0.3310, real_score: 0.8354, fake_score: 0.0427
# Saving simp-img-0040.png
# Epoch [41/300], loss_g: 6.8487, loss_d: 4.1530, real_score: 0.9996, fake_score: 0.9578
# Saving simp-img-0041.png
# Epoch [42/300], loss_g: 3.7499, loss_d: 0.2249, real_score: 0.8931, fake_score: 0.0964
# Saving simp-img-0042.png
# Epoch [43/300], loss_g: 2.7595, loss_d: 0.3401, real_score: 0.8135, fake_score: 0.1007
# Saving simp-img-0043.png
# Epoch [44/300], loss_g: 4.4056, loss_d: 0.1194, real_score: 0.9728, fake_score: 0.0850
# Saving simp-img-0044.png
# Epoch [45/300], loss_g: 1.9947, loss_d: 0.6083, real_score: 0.7549, fake_score: 0.2346
# Saving simp-img-0045.png
# Epoch [46/300], loss_g: 3.0688, loss_d: 0.2196, real_score: 0.8994, fake_score: 0.0943
# Saving simp-img-0046.png
# Epoch [47/300], loss_g: 4.6256, loss_d: 0.1190, real_score: 0.9649, fake_score: 0.0771
# Saving simp-img-0047.png
# Epoch [48/300], loss_g: 1.2014, loss_d: 0.4324, real_score: 0.6688, fake_score: 0.0010
# Saving simp-img-0048.png
# Epoch [49/300], loss_g: 2.8321, loss_d: 0.2349, real_score: 0.8645, fake_score: 0.0606
# Saving simp-img-0049.png
# Epoch [50/300], loss_g: 4.9837, loss_d: 0.0492, real_score: 0.9896, fake_score: 0.0358
# Saving simp-img-0050.png
# Epoch [51/300], loss_g: 3.7283, loss_d: 0.1438, real_score: 0.9344, fake_score: 0.0696
# Saving simp-img-0051.png
# Epoch [52/300], loss_g: 4.0235, loss_d: 0.3009, real_score: 0.9246, fake_score: 0.1797
# Saving simp-img-0052.png
# Epoch [53/300], loss_g: 2.8676, loss_d: 0.1847, real_score: 0.8980, fake_score: 0.0658
# Saving simp-img-0053.png
# Epoch [54/300], loss_g: 4.6687, loss_d: 0.0475, real_score: 0.9787, fake_score: 0.0249
# Saving simp-img-0054.png
# Epoch [55/300], loss_g: 3.5316, loss_d: 0.1070, real_score: 0.9391, fake_score: 0.0396
# Saving simp-img-0055.png
# Epoch [56/300], loss_g: 2.1675, loss_d: 0.2198, real_score: 0.8419, fake_score: 0.0295
# Saving simp-img-0056.png
# Epoch [57/300], loss_g: 4.6167, loss_d: 0.0819, real_score: 0.9690, fake_score: 0.0474
# Saving simp-img-0057.png
# Epoch [58/300], loss_g: 4.5192, loss_d: 0.0278, real_score: 0.9852, fake_score: 0.0125
# Saving simp-img-0058.png
# Epoch [59/300], loss_g: 2.8057, loss_d: 0.2108, real_score: 0.8920, fake_score: 0.0846
# Saving simp-img-0059.png
# Epoch [60/300], loss_g: 3.7766, loss_d: 0.1059, real_score: 0.9457, fake_score: 0.0457
# Saving simp-img-0060.png
# Epoch [61/300], loss_g: 3.3494, loss_d: 0.1503, real_score: 0.9180, fake_score: 0.0497
# Saving simp-img-0061.png
# Epoch [62/300], loss_g: 3.9531, loss_d: 0.0725, real_score: 0.9604, fake_score: 0.0302
# Saving simp-img-0062.png
# Epoch [63/300], loss_g: 4.2157, loss_d: 0.1218, real_score: 0.9613, fake_score: 0.0718
# Saving simp-img-0063.png
# Epoch [64/300], loss_g: 3.0479, loss_d: 0.1008, real_score: 0.9260, fake_score: 0.0222
# Saving simp-img-0064.png
# Epoch [65/300], loss_g: 0.7238, loss_d: 0.2631, real_score: 0.8092, fake_score: 0.0340
# Saving simp-img-0065.png
# Epoch [66/300], loss_g: 3.3221, loss_d: 0.0829, real_score: 0.9538, fake_score: 0.0335
# Saving simp-img-0066.png
# Epoch [67/300], loss_g: 2.8362, loss_d: 0.0645, real_score: 0.9631, fake_score: 0.0251
# Saving simp-img-0067.png
# Epoch [68/300], loss_g: 1.8623, loss_d: 0.4044, real_score: 0.7454, fake_score: 0.0880
# Saving simp-img-0068.png
# Epoch [69/300], loss_g: 2.5839, loss_d: 0.1711, real_score: 0.8630, fake_score: 0.0166
# Saving simp-img-0069.png
# Epoch [70/300], loss_g: 4.6196, loss_d: 0.0339, real_score: 0.9961, fake_score: 0.0291
# Saving simp-img-0070.png
# Epoch [71/300], loss_g: 2.7640, loss_d: 0.1323, real_score: 0.9168, fake_score: 0.0412
# Saving simp-img-0071.png
# Epoch [72/300], loss_g: 3.0171, loss_d: 0.0828, real_score: 0.9431, fake_score: 0.0215
# Saving simp-img-0072.png
# Epoch [73/300], loss_g: 2.7978, loss_d: 0.1822, real_score: 0.9090, fake_score: 0.0760
# Saving simp-img-0073.png
# Epoch [74/300], loss_g: 3.5868, loss_d: 0.1121, real_score: 0.9476, fake_score: 0.0535
# Saving simp-img-0074.png
# Epoch [75/300], loss_g: 4.8271, loss_d: 0.0310, real_score: 0.9900, fake_score: 0.0204
# Saving simp-img-0075.png
# Epoch [76/300], loss_g: 2.0623, loss_d: 0.5492, real_score: 0.8023, fake_score: 0.2262
# Saving simp-img-0076.png
# Epoch [77/300], loss_g: 3.6550, loss_d: 0.2062, real_score: 0.9285, fake_score: 0.1148
# Saving simp-img-0077.png
# Epoch [78/300], loss_g: 4.3535, loss_d: 0.1024, real_score: 0.9733, fake_score: 0.0662
# Saving simp-img-0078.png
# Epoch [79/300], loss_g: 3.9133, loss_d: 0.0847, real_score: 0.9878, fake_score: 0.0675
# Saving simp-img-0079.png
# Epoch [80/300], loss_g: 2.7928, loss_d: 0.3857, real_score: 0.8408, fake_score: 0.1690
# Saving simp-img-0080.png
# Epoch [81/300], loss_g: 3.1794, loss_d: 0.1267, real_score: 0.9234, fake_score: 0.0408
# Saving simp-img-0081.png
# Epoch [82/300], loss_g: 0.3567, loss_d: 0.2304, real_score: 0.8267, fake_score: 0.0227
# Saving simp-img-0082.png
# Epoch [83/300], loss_g: 3.3543, loss_d: 0.1016, real_score: 0.9457, fake_score: 0.0423
# Saving simp-img-0083.png
# Epoch [84/300], loss_g: 5.3267, loss_d: 0.0462, real_score: 0.9917, fake_score: 0.0354
# Saving simp-img-0084.png
# Epoch [85/300], loss_g: 3.9485, loss_d: 0.0827, real_score: 0.9436, fake_score: 0.0218
# Saving simp-img-0085.png
# Epoch [86/300], loss_g: 3.7781, loss_d: 0.1138, real_score: 0.9645, fake_score: 0.0690
# Saving simp-img-0086.png
# Epoch [87/300], loss_g: 3.4388, loss_d: 0.0922, real_score: 0.9327, fake_score: 0.0192
# Saving simp-img-0087.png
# Epoch [88/300], loss_g: 3.0533, loss_d: 0.0763, real_score: 0.9465, fake_score: 0.0195
# Saving simp-img-0088.png
# Epoch [89/300], loss_g: 3.6424, loss_d: 0.0876, real_score: 0.9641, fake_score: 0.0464
# Saving simp-img-0089.png
# Epoch [90/300], loss_g: 4.2434, loss_d: 0.0500, real_score: 0.9772, fake_score: 0.0259
# Saving simp-img-0090.png
# Epoch [91/300], loss_g: 3.7445, loss_d: 0.0477, real_score: 0.9742, fake_score: 0.0204
# Saving simp-img-0091.png
# Epoch [92/300], loss_g: 5.3415, loss_d: 0.0304, real_score: 0.9966, fake_score: 0.0257
# Saving simp-img-0092.png
# Epoch [93/300], loss_g: 2.5429, loss_d: 1.1886, real_score: 0.8025, fake_score: 0.5121
# Saving simp-img-0093.png
# Epoch [94/300], loss_g: 3.9380, loss_d: 0.2443, real_score: 0.9210, fake_score: 0.1348
# Saving simp-img-0094.png
# Epoch [95/300], loss_g: 3.6996, loss_d: 0.1457, real_score: 0.9506, fake_score: 0.0855
# Saving simp-img-0095.png
# Epoch [96/300], loss_g: 4.3022, loss_d: 0.1257, real_score: 0.9769, fake_score: 0.0877
# Saving simp-img-0096.png
# Epoch [97/300], loss_g: 4.9668, loss_d: 0.0369, real_score: 0.9881, fake_score: 0.0239
# Saving simp-img-0097.png
# Epoch [98/300], loss_g: 4.8914, loss_d: 0.0537, real_score: 0.9649, fake_score: 0.0169
# Saving simp-img-0098.png
# Epoch [99/300], loss_g: 4.8820, loss_d: 0.0421, real_score: 0.9800, fake_score: 0.0213
# Saving simp-img-0099.png
# Epoch [100/300], loss_g: 4.9108, loss_d: 0.0282, real_score: 0.9815, fake_score: 0.0092
# Saving simp-img-0100.png
# Epoch [101/300], loss_g: 3.1845, loss_d: 0.0555, real_score: 0.9589, fake_score: 0.0122
# Saving simp-img-0101.png
# Epoch [102/300], loss_g: 4.4158, loss_d: 0.0405, real_score: 0.9722, fake_score: 0.0117
# Saving simp-img-0102.png
# Epoch [103/300], loss_g: 4.4369, loss_d: 0.0775, real_score: 0.9619, fake_score: 0.0344
# Saving simp-img-0103.png
# Epoch [104/300], loss_g: 4.7248, loss_d: 0.0444, real_score: 0.9889, fake_score: 0.0316
# Saving simp-img-0104.png
# Epoch [105/300], loss_g: 0.0020, loss_d: 0.5821, real_score: 0.6118, fake_score: 0.0014
# Saving simp-img-0105.png
# Epoch [106/300], loss_g: 4.8917, loss_d: 0.4765, real_score: 0.9712, fake_score: 0.3028
# Saving simp-img-0106.png
# Epoch [107/300], loss_g: 12.1424, loss_d: 2.0383, real_score: 0.9994, fake_score: 0.8023
# Saving simp-img-0107.png
# Epoch [108/300], loss_g: 4.8979, loss_d: 0.0542, real_score: 0.9904, fake_score: 0.0422
# Saving simp-img-0108.png
# Epoch [109/300], loss_g: 3.8862, loss_d: 0.0903, real_score: 0.9720, fake_score: 0.0554
# Saving simp-img-0109.png
# Epoch [110/300], loss_g: 4.8186, loss_d: 0.0430, real_score: 0.9741, fake_score: 0.0160
# Saving simp-img-0110.png
# Epoch [111/300], loss_g: 4.7846, loss_d: 0.0244, real_score: 0.9863, fake_score: 0.0104
# Saving simp-img-0111.png
# Epoch [112/300], loss_g: 5.2091, loss_d: 0.0270, real_score: 0.9788, fake_score: 0.0054
# Saving simp-img-0112.png
# Epoch [113/300], loss_g: 4.3547, loss_d: 0.0504, real_score: 0.9835, fake_score: 0.0322
# Saving simp-img-0113.png
# Epoch [114/300], loss_g: 4.5280, loss_d: 0.0425, real_score: 0.9751, fake_score: 0.0167
# Saving simp-img-0114.png
# Epoch [115/300], loss_g: 5.3460, loss_d: 0.0160, real_score: 0.9910, fake_score: 0.0069
# Saving simp-img-0115.png
# Epoch [116/300], loss_g: 0.0000, loss_d: 100.0000, real_score: 1.0000, fake_score: 1.0000
# Saving simp-img-0116.png
# Epoch [117/300], loss_g: 0.0000, loss_d: 100.0000, real_score: 1.0000, fake_score: 1.0000
# Saving simp-img-0117.png
# Epoch [118/300], loss_g: 0.0000, loss_d: 100.0000, real_score: 1.0000, fake_score: 1.0000
# Saving simp-img-0118.png
# Epoch [119/300], loss_g: 0.0000, loss_d: 100.0000, real_score: 1.0000, fake_score: 1.0000
# Saving simp-img-0119.png
# Epoch [120/300], loss_g: 0.0000, loss_d: 100.0000, real_score: 1.0000, fake_score: 1.0000
# Saving simp-img-0120.png
# Epoch [121/300], loss_g: 0.0000, loss_d: 100.0000, real_score: 1.0000, fake_score: 1.0000
# Saving simp-img-0121.png
# Epoch [122/300], loss_g: 0.0000, loss_d: 100.0000, real_score: 1.0000, fake_score: 1.0000
# Saving simp-img-0122.png
# Epoch [123/300], loss_g: 0.0000, loss_d: 100.0000, real_score: 1.0000, fake_score: 1.0000
# Saving simp-img-0123.png
# Epoch [124/300], loss_g: 0.0000, loss_d: 100.0000, real_score: 1.0000, fake_score: 1.0000
# Saving simp-img-0124.png
# Epoch [125/300], loss_g: 0.0000, loss_d: 100.0000, real_score: 1.0000, fake_score: 1.0000
# Saving simp-img-0125.png
# Epoch [126/300], loss_g: 0.0000, loss_d: 100.0000, real_score: 1.0000, fake_score: 1.0000
# Saving simp-img-0126.png
# Epoch [127/300], loss_g: 0.0000, loss_d: 100.0000, real_score: 1.0000, fake_score: 1.0000
# Saving simp-img-0127.png
# Epoch [128/300], loss_g: 0.0000, loss_d: 100.0000, real_score: 1.0000, fake_score: 1.0000
# Saving simp-img-0128.png
# Epoch [129/300], loss_g: 0.0000, loss_d: 100.0000, real_score: 1.0000, fake_score: 1.0000
# Saving simp-img-0129.png
# Epoch [130/300], loss_g: 0.0000, loss_d: 100.0000, real_score: 1.0000, fake_score: 1.0000
# Saving simp-img-0130.png
# Epoch [131/300], loss_g: 0.0000, loss_d: 100.0000, real_score: 1.0000, fake_score: 1.0000
# Saving simp-img-0131.png
# Epoch [132/300], loss_g: 0.0000, loss_d: 100.0000, real_score: 1.0000, fake_score: 1.0000
# Saving simp-img-0132.png
# Epoch [133/300], loss_g: 0.0000, loss_d: 100.0000, real_score: 1.0000, fake_score: 1.0000
# Saving simp-img-0133.png
# Epoch [134/300], loss_g: 0.0000, loss_d: 100.0000, real_score: 1.0000, fake_score: 1.0000
# Saving simp-img-0134.png
# Epoch [135/300], loss_g: 0.0000, loss_d: 100.0000, real_score: 1.0000, fake_score: 1.0000
# Saving simp-img-0135.png
# Epoch [136/300], loss_g: 0.0000, loss_d: 100.0000, real_score: 1.0000, fake_score: 1.0000
# Saving simp-img-0136.png
# Epoch [137/300], loss_g: 0.0000, loss_d: 100.0000, real_score: 1.0000, fake_score: 1.0000
# Saving simp-img-0137.png
# Epoch [138/300], loss_g: 0.0000, loss_d: 100.0000, real_score: 1.0000, fake_score: 1.0000
# Saving simp-img-0138.png
# Epoch [139/300], loss_g: 0.0000, loss_d: 100.0000, real_score: 1.0000, fake_score: 1.0000
# Saving simp-img-0139.png
# Epoch [140/300], loss_g: 0.0000, loss_d: 100.0000, real_score: 1.0000, fake_score: 1.0000
# Saving simp-img-0140.png
# Epoch [141/300], loss_g: 0.0000, loss_d: 100.0000, real_score: 1.0000, fake_score: 1.0000
# Saving simp-img-0141.png
# Epoch [142/300], loss_g: 0.0000, loss_d: 100.0000, real_score: 1.0000, fake_score: 1.0000
# Saving simp-img-0142.png
# Epoch [143/300], loss_g: 0.0000, loss_d: 100.0000, real_score: 1.0000, fake_score: 1.0000
# Saving simp-img-0143.png
# Epoch [144/300], loss_g: 0.0000, loss_d: 100.0000, real_score: 1.0000, fake_score: 1.0000
# Saving simp-img-0144.png
# Epoch [145/300], loss_g: 0.0000, loss_d: 100.0000, real_score: 1.0000, fake_score: 1.0000
# Saving simp-img-0145.png
# Epoch [146/300], loss_g: 0.0000, loss_d: 100.0000, real_score: 1.0000, fake_score: 1.0000
# Saving simp-img-0146.png
# Epoch [147/300], loss_g: 0.0000, loss_d: 100.0000, real_score: 1.0000, fake_score: 1.0000
# Saving simp-img-0147.png
# Epoch [148/300], loss_g: 0.0000, loss_d: 100.0000, real_score: 1.0000, fake_score: 1.0000
# Saving simp-img-0148.png
# Epoch [149/300], loss_g: 0.0000, loss_d: 100.0000, real_score: 1.0000, fake_score: 1.0000
# Saving simp-img-0149.png
# Epoch [150/300], loss_g: 0.0000, loss_d: 100.0000, real_score: 1.0000, fake_score: 1.0000
# Saving simp-img-0150.png
# Epoch [151/300], loss_g: 0.0000, loss_d: 100.0000, real_score: 1.0000, fake_score: 1.0000
# Saving simp-img-0151.png
# Epoch [152/300], loss_g: 0.0000, loss_d: 100.0000, real_score: 1.0000, fake_score: 1.0000
# Saving simp-img-0152.png
# Epoch [153/300], loss_g: 0.0000, loss_d: 100.0000, real_score: 1.0000, fake_score: 1.0000
# Saving simp-img-0153.png
# Epoch [154/300], loss_g: 0.0000, loss_d: 100.0000, real_score: 1.0000, fake_score: 1.0000
# Saving simp-img-0154.png
# Epoch [155/300], loss_g: 0.0000, loss_d: 100.0000, real_score: 1.0000, fake_score: 1.0000
# Saving simp-img-0155.png
# Epoch [156/300], loss_g: 0.0000, loss_d: 100.0000, real_score: 1.0000, fake_score: 1.0000
# Saving simp-img-0156.png
# Epoch [157/300], loss_g: 0.0000, loss_d: 100.0000, real_score: 1.0000, fake_score: 1.0000
# Saving simp-img-0157.png
# Epoch [158/300], loss_g: 0.0000, loss_d: 100.0000, real_score: 1.0000, fake_score: 1.0000
# Saving simp-img-0158.png
# Epoch [159/300], loss_g: 0.0000, loss_d: 100.0000, real_score: 1.0000, fake_score: 1.0000
# Saving simp-img-0159.png
# Epoch [160/300], loss_g: 0.0000, loss_d: 100.0000, real_score: 1.0000, fake_score: 1.0000
# Saving simp-img-0160.png
# Epoch [161/300], loss_g: 0.0000, loss_d: 100.0000, real_score: 1.0000, fake_score: 1.0000
# Saving simp-img-0161.png
# Epoch [162/300], loss_g: 0.0000, loss_d: 100.0000, real_score: 1.0000, fake_score: 1.0000
# Saving simp-img-0162.png
# Epoch [163/300], loss_g: 0.0000, loss_d: 100.0000, real_score: 1.0000, fake_score: 1.0000
# Saving simp-img-0163.png
# Epoch [164/300], loss_g: 0.0000, loss_d: 100.0000, real_score: 1.0000, fake_score: 1.0000
# Saving simp-img-0164.png
# Epoch [165/300], loss_g: 0.0000, loss_d: 100.0000, real_score: 1.0000, fake_score: 1.0000
# Saving simp-img-0165.png
# Epoch [166/300], loss_g: 0.0000, loss_d: 100.0000, real_score: 1.0000, fake_score: 1.0000
# Saving simp-img-0166.png
# Epoch [167/300], loss_g: 0.0000, loss_d: 100.0000, real_score: 1.0000, fake_score: 1.0000
# Saving simp-img-0167.png
# Epoch [168/300], loss_g: 0.0000, loss_d: 100.0000, real_score: 1.0000, fake_score: 1.0000
# Saving simp-img-0168.png
# Epoch [169/300], loss_g: 0.0000, loss_d: 100.0000, real_score: 1.0000, fake_score: 1.0000
# Saving simp-img-0169.png
# Epoch [170/300], loss_g: 0.0000, loss_d: 100.0000, real_score: 1.0000, fake_score: 1.0000
# Saving simp-img-0170.png
# Epoch [171/300], loss_g: 0.0000, loss_d: 100.0000, real_score: 1.0000, fake_score: 1.0000
# Saving simp-img-0171.png
# Epoch [172/300], loss_g: 0.0000, loss_d: 100.0000, real_score: 1.0000, fake_score: 1.0000
# Saving simp-img-0172.png
# Epoch [173/300], loss_g: 0.0000, loss_d: 100.0000, real_score: 1.0000, fake_score: 1.0000
# Saving simp-img-0173.png
# Epoch [174/300], loss_g: 0.0000, loss_d: 100.0000, real_score: 1.0000, fake_score: 1.0000
# Saving simp-img-0174.png
# Epoch [175/300], loss_g: 0.0000, loss_d: 100.0000, real_score: 1.0000, fake_score: 1.0000
# Saving simp-img-0175.png
# Epoch [176/300], loss_g: 0.0000, loss_d: 100.0000, real_score: 1.0000, fake_score: 1.0000
# Saving simp-img-0176.png
# Epoch [177/300], loss_g: 0.0000, loss_d: 100.0000, real_score: 1.0000, fake_score: 1.0000
# Saving simp-img-0177.png
# Epoch [178/300], loss_g: 0.0000, loss_d: 100.0000, real_score: 1.0000, fake_score: 1.0000
# Saving simp-img-0178.png
# Epoch [179/300], loss_g: 0.0000, loss_d: 100.0000, real_score: 1.0000, fake_score: 1.0000
# Saving simp-img-0179.png
# Epoch [180/300], loss_g: 0.0000, loss_d: 100.0000, real_score: 1.0000, fake_score: 1.0000
# Saving simp-img-0180.png
# Epoch [181/300], loss_g: 0.0000, loss_d: 100.0000, real_score: 1.0000, fake_score: 1.0000
# Saving simp-img-0181.png
# Epoch [182/300], loss_g: 0.0000, loss_d: 100.0000, real_score: 1.0000, fake_score: 1.0000
# Saving simp-img-0182.png
# Epoch [183/300], loss_g: 0.0000, loss_d: 100.0000, real_score: 1.0000, fake_score: 1.0000
# Saving simp-img-0183.png
# Epoch [184/300], loss_g: 0.0000, loss_d: 100.0000, real_score: 1.0000, fake_score: 1.0000
# Saving simp-img-0184.png
# Epoch [185/300], loss_g: 0.0000, loss_d: 100.0000, real_score: 1.0000, fake_score: 1.0000
# Saving simp-img-0185.png
# Epoch [186/300], loss_g: 0.0000, loss_d: 100.0000, real_score: 1.0000, fake_score: 1.0000
# Saving simp-img-0186.png
# Epoch [187/300], loss_g: 0.0000, loss_d: 100.0000, real_score: 1.0000, fake_score: 1.0000
# Saving simp-img-0187.png
# Epoch [188/300], loss_g: 0.0000, loss_d: 100.0000, real_score: 1.0000, fake_score: 1.0000
# Saving simp-img-0188.png
# Epoch [189/300], loss_g: 0.0000, loss_d: 100.0000, real_score: 1.0000, fake_score: 1.0000
# Saving simp-img-0189.png
# Epoch [190/300], loss_g: 0.0000, loss_d: 100.0000, real_score: 1.0000, fake_score: 1.0000
# Saving simp-img-0190.png
# Epoch [191/300], loss_g: 0.0000, loss_d: 100.0000, real_score: 1.0000, fake_score: 1.0000
# Saving simp-img-0191.png
# Epoch [192/300], loss_g: 0.0000, loss_d: 100.0000, real_score: 1.0000, fake_score: 1.0000
# Saving simp-img-0192.png
# Epoch [193/300], loss_g: 0.0000, loss_d: 100.0000, real_score: 1.0000, fake_score: 1.0000
# Saving simp-img-0193.png
# Epoch [194/300], loss_g: 0.0000, loss_d: 100.0000, real_score: 1.0000, fake_score: 1.0000
# Saving simp-img-0194.png
# Epoch [195/300], loss_g: 0.0000, loss_d: 100.0000, real_score: 1.0000, fake_score: 1.0000
# Saving simp-img-0195.png
# Epoch [196/300], loss_g: 0.0000, loss_d: 100.0000, real_score: 1.0000, fake_score: 1.0000
# Saving simp-img-0196.png
# Epoch [197/300], loss_g: 0.0000, loss_d: 100.0000, real_score: 1.0000, fake_score: 1.0000
# Saving simp-img-0197.png
# Epoch [198/300], loss_g: 0.0000, loss_d: 100.0000, real_score: 1.0000, fake_score: 1.0000
# Saving simp-img-0198.png
# Epoch [199/300], loss_g: 0.0000, loss_d: 100.0000, real_score: 1.0000, fake_score: 1.0000
# Saving simp-img-0199.png
# Epoch [200/300], loss_g: 0.0000, loss_d: 100.0000, real_score: 1.0000, fake_score: 1.0000
# Saving simp-img-0200.png
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_151075/4004142291.py in <module>
# ----> 1 history = fit(epochs, lr,start_idx=1)
#
# /tmp/ipykernel_151075/2845868582.py in fit(epochs, lr, start_idx)
#      15         for real_images, _ in (train_dl):
#      16             # Train discriminator
# ---> 17             loss_d, real_score, fake_score = train_discriminator(real_images, opt_d)
#      18             # Train generator
#      19             loss_g = train_generator(opt_g)
#
# /tmp/ipykernel_151075/2100296819.py in train_discriminator(real_images, opt_d)
#      17     fake_preds = discriminator(fake_images)
#      18     fake_loss = F.binary_cross_entropy(fake_preds, fake_targets)
# ---> 19     fake_score = torch.mean(fake_preds).item()
#      20
#      21     # Update discriminator weights
#
# KeyboardInterrupt:

# %%
torch.save(generator.state_dict(), 'G_simpsons.pth')
torch.save(discriminator.state_dict(), 'D_simpsons.pth')

# %%
import cv2
import os

vid_fname = 'simpsons_gans.mp4'
frame = cv2.imread("simp_generation_1/simp-img-0000.png")
height, width, layers = frame.shape


#insering frames into video
video = cv2.VideoWriter("./simp_gan.avi", 0,10, (width, height)) 
files = os.listdir("simp_generation_1")
files.sort()
for i in files: 
   video.write(cv2.imread("simp_generation_1/"+i)) 
   print(i)
# Out:
# simp-img-0000.png
# simp-img-0001.png
# simp-img-0002.png
# simp-img-0003.png
# simp-img-0004.png
# simp-img-0005.png
# simp-img-0006.png
# simp-img-0007.png
# simp-img-0008.png
# simp-img-0009.png
# simp-img-0010.png
# simp-img-0011.png
# simp-img-0012.png
# simp-img-0013.png
# simp-img-0014.png
# simp-img-0015.png
# simp-img-0016.png
# simp-img-0017.png
# simp-img-0018.png
# simp-img-0019.png
# simp-img-0020.png
# simp-img-0021.png
# simp-img-0022.png
# simp-img-0023.png
# simp-img-0024.png
# simp-img-0025.png
# simp-img-0026.png
# simp-img-0027.png
# simp-img-0028.png
# simp-img-0029.png
# simp-img-0030.png
# simp-img-0031.png
# simp-img-0032.png
# simp-img-0033.png
# simp-img-0034.png
# simp-img-0035.png
# simp-img-0036.png
# simp-img-0037.png
# simp-img-0038.png
# simp-img-0039.png
# simp-img-0040.png
# simp-img-0041.png
# simp-img-0042.png
# simp-img-0043.png
# simp-img-0044.png
# simp-img-0045.png
# simp-img-0046.png
# simp-img-0047.png
# simp-img-0048.png
# simp-img-0049.png
# simp-img-0050.png
# simp-img-0051.png
# simp-img-0052.png
# simp-img-0053.png
# simp-img-0054.png
# simp-img-0055.png
# simp-img-0056.png
# simp-img-0057.png
# simp-img-0058.png
# simp-img-0059.png
# simp-img-0060.png
# simp-img-0061.png
# simp-img-0062.png
# simp-img-0063.png
# simp-img-0064.png
# simp-img-0065.png
# simp-img-0066.png
# simp-img-0067.png
# simp-img-0068.png
# simp-img-0069.png
# simp-img-0070.png
# simp-img-0071.png
# simp-img-0072.png
# simp-img-0073.png
# simp-img-0074.png
# simp-img-0075.png
# simp-img-0076.png
# simp-img-0077.png
# simp-img-0078.png
# simp-img-0079.png
# simp-img-0080.png
# simp-img-0081.png
# simp-img-0082.png
# simp-img-0083.png
# simp-img-0084.png
# simp-img-0085.png
# simp-img-0086.png
# simp-img-0087.png
# simp-img-0088.png
# simp-img-0089.png
# simp-img-0090.png
# simp-img-0091.png
# simp-img-0092.png
# simp-img-0093.png
# simp-img-0094.png
# simp-img-0095.png
# simp-img-0096.png
# simp-img-0097.png
# simp-img-0098.png
# simp-img-0099.png
# simp-img-0100.png
# simp-img-0101.png
# simp-img-0102.png
# simp-img-0103.png
# simp-img-0104.png
# simp-img-0105.png
# simp-img-0106.png
# simp-img-0107.png
# simp-img-0108.png
# simp-img-0109.png
# simp-img-0110.png
# simp-img-0111.png
# simp-img-0112.png
# simp-img-0113.png
# simp-img-0114.png
# simp-img-0115.png
# simp-img-0116.png
# simp-img-0117.png
# simp-img-0118.png
# simp-img-0119.png
# simp-img-0120.png
# simp-img-0121.png
# simp-img-0122.png
# simp-img-0123.png
# simp-img-0124.png
# simp-img-0125.png
# simp-img-0126.png
# simp-img-0127.png
# simp-img-0128.png
# simp-img-0129.png
# simp-img-0130.png
# simp-img-0131.png
# simp-img-0132.png
# simp-img-0133.png
# simp-img-0134.png
# simp-img-0135.png
# simp-img-0136.png
# simp-img-0137.png
# simp-img-0138.png
# simp-img-0139.png
# simp-img-0140.png
# simp-img-0141.png
# simp-img-0142.png
# simp-img-0143.png
# simp-img-0144.png
# simp-img-0145.png
# simp-img-0146.png
# simp-img-0147.png
# simp-img-0148.png
# simp-img-0149.png
# simp-img-0150.png
# simp-img-0151.png
# simp-img-0152.png
# simp-img-0153.png
# simp-img-0154.png
# simp-img-0155.png
# simp-img-0156.png
# simp-img-0157.png
# simp-img-0158.png
# simp-img-0159.png
# simp-img-0160.png
# simp-img-0161.png
# simp-img-0162.png
# simp-img-0163.png
# simp-img-0164.png
# simp-img-0165.png
# simp-img-0166.png
# simp-img-0167.png
# simp-img-0168.png
# simp-img-0169.png
# simp-img-0170.png
# simp-img-0171.png
# simp-img-0172.png
# simp-img-0173.png
# simp-img-0174.png
# simp-img-0175.png
# simp-img-0176.png
# simp-img-0177.png
# simp-img-0178.png
# simp-img-0179.png
# simp-img-0180.png
# simp-img-0181.png
# simp-img-0182.png
# simp-img-0183.png
# simp-img-0184.png
# simp-img-0185.png
# simp-img-0186.png
# simp-img-0187.png
# simp-img-0188.png
# simp-img-0189.png
# simp-img-0190.png
# simp-img-0191.png
# simp-img-0192.png
# simp-img-0193.png
# simp-img-0194.png
# simp-img-0195.png
# simp-img-0196.png
# simp-img-0197.png
# simp-img-0198.png
# simp-img-0199.png
# simp-img-0200.png

# %%
print(os.listdir("simp_generation_1"))
# Out:
# ['simp-img-0023.png', 'simp-img-0045.png', 'simp-img-0082.png', 'simp-img-0013.png', 'simp-img-0100.png', 'simp-img-0177.png', 'simp-img-0049.png', 'simp-img-0004.png', 'simp-img-0083.png', 'simp-img-0062.png', 'simp-img-0137.png', 'simp-img-0197.png', 'simp-img-0148.png', 'simp-img-0180.png', 'simp-img-0090.png', 'simp-img-0088.png', 'simp-img-0154.png', 'simp-img-0069.png', 'simp-img-0187.png', 'simp-img-0149.png', 'simp-img-0020.png', 'simp-img-0162.png', 'simp-img-0074.png', 'simp-img-0097.png', 'simp-img-0005.png', 'simp-img-0038.png', 'simp-img-0140.png', 'simp-img-0000.png', 'simp-img-0067.png', 'simp-img-0163.png', 'simp-img-0022.png', 'simp-img-0092.png', 'simp-img-0103.png', 'simp-img-0129.png', 'simp-img-0007.png', 'simp-img-0118.png', 'simp-img-0125.png', 'simp-img-0101.png', 'simp-img-0059.png', 'simp-img-0077.png', 'simp-img-0102.png', 'simp-img-0168.png', 'simp-img-0182.png', 'simp-img-0186.png', 'simp-img-0190.png', 'simp-img-0184.png', 'simp-img-0157.png', 'simp-img-0041.png', 'simp-img-0016.png', 'simp-img-0052.png', 'simp-img-0193.png', 'simp-img-0027.png', 'simp-img-0009.png', 'simp-img-0019.png', 'simp-img-0139.png', 'simp-img-0122.png', 'simp-img-0106.png', 'simp-img-0144.png', 'simp-img-0130.png', 'simp-img-0141.png', 'simp-img-0078.png', 'simp-img-0171.png', 'simp-img-0091.png', 'simp-img-0001.png', 'simp-img-0044.png', 'simp-img-0053.png', 'simp-img-0046.png', 'simp-img-0061.png', 'simp-img-0024.png', 'simp-img-0017.png', 'simp-img-0188.png', 'simp-img-0089.png', 'simp-img-0176.png', 'simp-img-0098.png', 'simp-img-0191.png', 'simp-img-0134.png', 'simp-img-0116.png', 'simp-img-0037.png', 'simp-img-0070.png', 'simp-img-0072.png', 'simp-img-0199.png', 'simp-img-0189.png', 'simp-img-0143.png', 'simp-img-0028.png', 'simp-img-0159.png', 'simp-img-0010.png', 'simp-img-0192.png', 'simp-img-0018.png', 'simp-img-0147.png', 'simp-img-0153.png', 'simp-img-0142.png', 'simp-img-0035.png', 'simp-img-0196.png', 'simp-img-0051.png', 'simp-img-0065.png', 'simp-img-0128.png', 'simp-img-0123.png', 'simp-img-0006.png', 'simp-img-0138.png', 'simp-img-0164.png', 'simp-img-0117.png', 'simp-img-0031.png', 'simp-img-0167.png', 'simp-img-0115.png', 'simp-img-0156.png', 'simp-img-0095.png', 'simp-img-0145.png', 'simp-img-0047.png', 'simp-img-0011.png', 'simp-img-0127.png', 'simp-img-0155.png', 'simp-img-0014.png', 'simp-img-0008.png', 'simp-img-0133.png', 'simp-img-0081.png', 'simp-img-0158.png', 'simp-img-0073.png', 'simp-img-0173.png', 'simp-img-0113.png', 'simp-img-0085.png', 'simp-img-0121.png', 'simp-img-0170.png', 'simp-img-0071.png', 'simp-img-0040.png', 'simp-img-0131.png', 'simp-img-0136.png', 'simp-img-0066.png', 'simp-img-0084.png', 'simp-img-0179.png', 'simp-img-0075.png', 'simp-img-0060.png', 'simp-img-0002.png', 'simp-img-0036.png', 'simp-img-0021.png', 'simp-img-0175.png', 'simp-img-0152.png', 'simp-img-0063.png', 'simp-img-0119.png', 'simp-img-0039.png', 'simp-img-0126.png', 'simp-img-0135.png', 'simp-img-0076.png', 'simp-img-0026.png', 'simp-img-0124.png', 'simp-img-0185.png', 'simp-img-0172.png', 'simp-img-0080.png', 'simp-img-0109.png', 'simp-img-0058.png', 'simp-img-0048.png', 'simp-img-0099.png', 'simp-img-0194.png', 'simp-img-0064.png', 'simp-img-0198.png', 'simp-img-0003.png', 'simp-img-0050.png', 'simp-img-0025.png', 'simp-img-0108.png', 'simp-img-0110.png', 'simp-img-0169.png', 'simp-img-0093.png', 'simp-img-0132.png', 'simp-img-0079.png', 'simp-img-0146.png', 'simp-img-0057.png', 'simp-img-0160.png', 'simp-img-0195.png', 'simp-img-0096.png', 'simp-img-0056.png', 'simp-img-0165.png', 'simp-img-0033.png', 'simp-img-0200.png', 'simp-img-0030.png', 'simp-img-0114.png', 'simp-img-0043.png', 'simp-img-0087.png', 'simp-img-0183.png', 'simp-img-0178.png', 'simp-img-0181.png', 'simp-img-0054.png', 'simp-img-0112.png', 'simp-img-0055.png', 'simp-img-0120.png', 'simp-img-0151.png', 'simp-img-0012.png', 'simp-img-0111.png', 'simp-img-0174.png', 'simp-img-0150.png', 'simp-img-0032.png', 'simp-img-0029.png', 'simp-img ...
