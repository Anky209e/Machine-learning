# %%
import os

DATA_DIR = 'flower_data'
print(os.listdir(DATA_DIR))
# Out:
# ['images']

# %%
from torch.utils.data import DataLoader
from torchvision.datasets import ImageFolder
import torchvision.transforms as T

# %%
image_size = 64
batch_size = 128
stats = (0.5, 0.5, 0.5), (0.5, 0.5, 0.5)

# %%
train_ds = ImageFolder(DATA_DIR, transform=T.Compose([
    T.Resize(image_size),
    T.CenterCrop(image_size),
    T.ToTensor(),
    T.Normalize(*stats)]))

train_dl = DataLoader(train_ds, batch_size, shuffle=True, num_workers=3, pin_memory=True)

# %%
import torch
from torchvision.utils import make_grid
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def denorm(img_tensors):
    return img_tensors * stats[1][0] + stats[0][0]

# %%
def show_images(images, nmax=64):
    fig, ax = plt.subplots(figsize=(8, 8))
    ax.set_xticks([]); ax.set_yticks([])
    ax.imshow(make_grid(denorm(images.detach()[:nmax]), nrow=8).permute(1, 2, 0))

def show_batch(dl, nmax=64):
    for images, _ in dl:
        show_images(images, nmax)
        break

# %%
show_batch(train_dl)

# %%
def get_default_device():
    """Pick GPU if available, else CPU"""
    if torch.cuda.is_available():
        return torch.device('cuda')
    else:
        return torch.device('cpu')
    
def to_device(data, device):
    """Move tensor(s) to chosen device"""
    if isinstance(data, (list,tuple)):
        return [to_device(x, device) for x in data]
    return data.to(device, non_blocking=True)

class DeviceDataLoader():
    """Wrap a dataloader to move data to a device"""
    def __init__(self, dl, device):
        self.dl = dl
        self.device = device
        
    def __iter__(self):
        """Yield a batch of data after moving it to device"""
        for b in self.dl: 
            yield to_device(b, self.device)

    def __len__(self):
        """Number of batches"""
        return len(self.dl)

# %%
device = get_default_device()
device
# Out:
# device(type='cuda')

# %%
train_dl = DeviceDataLoader(train_dl, device)

# %%
import torch.nn as nn

# %%
discriminator = nn.Sequential(
    # in: 3 x 64 x 64

    nn.Conv2d(3, 64, kernel_size=4, stride=2, padding=1, bias=False),
    nn.BatchNorm2d(64),
    nn.LeakyReLU(0.2, inplace=True),
    # out: 64 x 32 x 32

    nn.Conv2d(64, 128, kernel_size=4, stride=2, padding=1, bias=False),
    nn.BatchNorm2d(128),
    nn.LeakyReLU(0.2, inplace=True),
    # out: 128 x 16 x 16

    nn.Conv2d(128, 256, kernel_size=4, stride=2, padding=1, bias=False),
    nn.BatchNorm2d(256),
    nn.LeakyReLU(0.2, inplace=True),
    # out: 256 x 8 x 8

    nn.Conv2d(256, 512, kernel_size=4, stride=2, padding=1, bias=False),
    nn.BatchNorm2d(512),
    nn.LeakyReLU(0.2, inplace=True),
    # out: 512 x 4 x 4

    nn.Conv2d(512, 1, kernel_size=4, stride=1, padding=0, bias=False),
    # out: 1 x 1 x 1

    nn.Flatten(),
    nn.Sigmoid())

# %%
discriminator = to_device(discriminator, device)

# %%
discriminator
# Out:
# Sequential(
#   (0): Conv2d(3, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): LeakyReLU(negative_slope=0.2, inplace=True)
#   (3): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (5): LeakyReLU(negative_slope=0.2, inplace=True)
#   (6): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (7): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (8): LeakyReLU(negative_slope=0.2, inplace=True)
#   (9): Conv2d(256, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (10): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (11): LeakyReLU(negative_slope=0.2, inplace=True)
#   (12): Conv2d(512, 1, kernel_size=(4, 4), stride=(1, 1), bias=False)
#   (13): Flatten(start_dim=1, end_dim=-1)
#   (14): Sigmoid()
# )

# %%
latent_size = 128

# %%
generator = nn.Sequential(
    # in: latent_size x 1 x 1

    nn.ConvTranspose2d(latent_size, 512, kernel_size=4, stride=1, padding=0, bias=False),
    nn.BatchNorm2d(512),
    nn.ReLU(True),
    # out: 512 x 4 x 4

    nn.ConvTranspose2d(512, 256, kernel_size=4, stride=2, padding=1, bias=False),
    nn.BatchNorm2d(256),
    nn.ReLU(True),
    # out: 256 x 8 x 8

    nn.ConvTranspose2d(256, 128, kernel_size=4, stride=2, padding=1, bias=False),
    nn.BatchNorm2d(128),
    nn.ReLU(True),
    # out: 128 x 16 x 16

    nn.ConvTranspose2d(128, 64, kernel_size=4, stride=2, padding=1, bias=False),
    nn.BatchNorm2d(64),
    nn.ReLU(True),
    # out: 64 x 32 x 32

    nn.ConvTranspose2d(64, 3, kernel_size=4, stride=2, padding=1, bias=False),
    nn.Tanh()
    # out: 3 x 64 x 64
)

# %%
xb = torch.randn(batch_size, latent_size, 1, 1) # random latent tensors
fake_images = generator(xb)
print(fake_images.shape)
show_images(fake_images)
# Out:
# torch.Size([128, 3, 64, 64])

# %%
generator = to_device(generator, device)

# %%
def train_discriminator(real_images, opt_d):
    # Clear discriminator gradients
    opt_d.zero_grad()

    # Pass real images through discriminator
    real_preds = discriminator(real_images)
    real_targets = torch.ones(real_images.size(0), 1, device=device)
    real_loss = F.binary_cross_entropy(real_preds, real_targets)
    real_score = torch.mean(real_preds).item()
    
    # Generate fake images
    latent = torch.randn(batch_size, latent_size, 1, 1, device=device)
    fake_images = generator(latent)

    # Pass fake images through discriminator
    fake_targets = torch.zeros(fake_images.size(0), 1, device=device)
    fake_preds = discriminator(fake_images)
    fake_loss = F.binary_cross_entropy(fake_preds, fake_targets)
    fake_score = torch.mean(fake_preds).item()

    # Update discriminator weights
    loss = real_loss + fake_loss
    loss.backward()
    opt_d.step()
    return loss.item(), real_score, fake_score

# %%
def train_generator(opt_g):
    # Clear generator gradients
    opt_g.zero_grad()
    
    # Generate fake images
    latent = torch.randn(batch_size, latent_size, 1, 1, device=device)
    fake_images = generator(latent)
    
    # Try to fool the discriminator
    preds = discriminator(fake_images)
    targets = torch.ones(batch_size, 1, device=device)
    loss = F.binary_cross_entropy(preds, targets)
    
    # Update generator weights
    loss.backward()
    opt_g.step()
    
    return loss.item()

# %%
from torchvision.utils import save_image

# %%
sample_dir = 'flower_gen1'
os.makedirs(sample_dir, exist_ok=True)

# %%
def save_samples(index, latent_tensors, show=True):
    fake_images = generator(latent_tensors)
    fake_fname = 'flower-{0:0=4d}.png'.format(index)
    save_image(denorm(fake_images), os.path.join(sample_dir, fake_fname), nrow=8)
    print('Saving', fake_fname)
    if show:
        fig, ax = plt.subplots(figsize=(8, 8))
        ax.set_xticks([]); ax.set_yticks([])
        ax.imshow(make_grid(fake_images.cpu().detach(), nrow=8).permute(1, 2, 0))

# %%
fixed_latent = torch.randn(64, latent_size, 1, 1, device=device)

# %%
save_samples(0, fixed_latent)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Saving flower-0000.png

# %%
import torch.nn.functional as F

# %%
def fit(epochs, lr, start_idx=1):
    torch.cuda.empty_cache()
    
    # Losses & scores
    losses_g = []
    losses_d = []
    real_scores = []
    fake_scores = []
    
    # Create optimizers
    opt_d = torch.optim.Adam(discriminator.parameters(), lr=lr, betas=(0.5, 0.999))
    opt_g = torch.optim.Adam(generator.parameters(), lr=lr, betas=(0.5, 0.999))
    
    for epoch in range(epochs):
        for real_images, _ in (train_dl):
            # Train discriminator
            loss_d, real_score, fake_score = train_discriminator(real_images, opt_d)
            # Train generator
            loss_g = train_generator(opt_g)
            
        # Record losses & scores
        losses_g.append(loss_g)
        losses_d.append(loss_d)
        real_scores.append(real_score)
        fake_scores.append(fake_score)
        
        # Log losses & scores (last batch)
        print("Epoch [{}/{}], loss_g: {:.4f}, loss_d: {:.4f}, real_score: {:.4f}, fake_score: {:.4f}".format(
            epoch+1, epochs, loss_g, loss_d, real_score, fake_score))
    
        # Save generated images
        save_samples(epoch+start_idx, fixed_latent, show=False)
    
    return losses_g, losses_d, real_scores, fake_scores

# %%
lr = 0.0002
epochs = 300

# %%
history = fit(epochs, lr,start_idx=301)
# Out:
# Epoch [1/300], loss_g: 8.6701, loss_d: 0.0158, real_score: 0.9858, fake_score: 0.0011
# Saving flower-0301.png
# Epoch [2/300], loss_g: 5.4146, loss_d: 0.0233, real_score: 0.9943, fake_score: 0.0170
# Saving flower-0302.png
# Epoch [3/300], loss_g: 6.2106, loss_d: 0.0327, real_score: 0.9961, fake_score: 0.0281
# Saving flower-0303.png
# Epoch [4/300], loss_g: 5.8534, loss_d: 0.0274, real_score: 0.9987, fake_score: 0.0250
# Saving flower-0304.png
# Epoch [5/300], loss_g: 6.1393, loss_d: 0.0068, real_score: 0.9969, fake_score: 0.0037
# Saving flower-0305.png
# Epoch [6/300], loss_g: 9.8813, loss_d: 0.0070, real_score: 0.9932, fake_score: 0.0001
# Saving flower-0306.png
# Epoch [7/300], loss_g: 9.5490, loss_d: 0.1741, real_score: 0.8808, fake_score: 0.0064
# Saving flower-0307.png
# Epoch [8/300], loss_g: 4.8489, loss_d: 0.2041, real_score: 0.9114, fake_score: 0.0882
# Saving flower-0308.png
# Epoch [9/300], loss_g: 7.3227, loss_d: 0.2141, real_score: 0.9947, fake_score: 0.1680
# Saving flower-0309.png
# Epoch [10/300], loss_g: 4.3824, loss_d: 0.0628, real_score: 0.9585, fake_score: 0.0188
# Saving flower-0310.png
# Epoch [11/300], loss_g: 5.8738, loss_d: 0.2159, real_score: 0.9694, fake_score: 0.1423
# Saving flower-0311.png
# Epoch [12/300], loss_g: 4.4343, loss_d: 0.0829, real_score: 0.9611, fake_score: 0.0389
# Saving flower-0312.png
# Epoch [13/300], loss_g: 6.4154, loss_d: 0.0770, real_score: 0.9896, fake_score: 0.0573
# Saving flower-0313.png
# Epoch [14/300], loss_g: 8.2438, loss_d: 0.0073, real_score: 0.9932, fake_score: 0.0004
# Saving flower-0314.png
# Epoch [15/300], loss_g: 7.1915, loss_d: 0.0041, real_score: 0.9986, fake_score: 0.0027
# Saving flower-0315.png
# Epoch [16/300], loss_g: 7.5579, loss_d: 0.0110, real_score: 0.9903, fake_score: 0.0011
# Saving flower-0316.png
# Epoch [17/300], loss_g: 6.8655, loss_d: 0.0171, real_score: 0.9856, fake_score: 0.0024
# Saving flower-0317.png
# Epoch [18/300], loss_g: 7.4954, loss_d: 0.0747, real_score: 0.9923, fake_score: 0.0587
# Saving flower-0318.png
# Epoch [19/300], loss_g: 7.6119, loss_d: 0.1239, real_score: 0.9682, fake_score: 0.0747
# Saving flower-0319.png
# Epoch [20/300], loss_g: 4.6654, loss_d: 0.4934, real_score: 0.6784, fake_score: 0.0023
# Saving flower-0320.png
# Epoch [21/300], loss_g: 6.7652, loss_d: 0.0872, real_score: 0.9347, fake_score: 0.0116
# Saving flower-0321.png
# Epoch [22/300], loss_g: 4.8740, loss_d: 0.0795, real_score: 0.9765, fake_score: 0.0511
# Saving flower-0322.png
# Epoch [23/300], loss_g: 1.4311, loss_d: 0.7394, real_score: 0.5876, fake_score: 0.0025
# Saving flower-0323.png
# Epoch [24/300], loss_g: 7.6977, loss_d: 0.0432, real_score: 0.9931, fake_score: 0.0328
# Saving flower-0324.png
# Epoch [25/300], loss_g: 6.2330, loss_d: 0.0980, real_score: 0.9988, fake_score: 0.0822
# Saving flower-0325.png
# Epoch [26/300], loss_g: 6.9290, loss_d: 0.0183, real_score: 0.9966, fake_score: 0.0145
# Saving flower-0326.png
# Epoch [27/300], loss_g: 6.8951, loss_d: 0.0464, real_score: 0.9575, fake_score: 0.0016
# Saving flower-0327.png
# Epoch [28/300], loss_g: 8.5017, loss_d: 0.0043, real_score: 0.9963, fake_score: 0.0005
# Saving flower-0328.png
# Epoch [29/300], loss_g: 7.4209, loss_d: 0.1164, real_score: 0.9980, fake_score: 0.1017
# Saving flower-0329.png
# Epoch [30/300], loss_g: 10.0431, loss_d: 0.0058, real_score: 0.9944, fake_score: 0.0001
# Saving flower-0330.png
# Epoch [31/300], loss_g: 4.2388, loss_d: 0.0099, real_score: 0.9986, fake_score: 0.0084
# Saving flower-0331.png
# Epoch [32/300], loss_g: 4.2952, loss_d: 0.4909, real_score: 0.7706, fake_score: 0.0029
# Saving flower-0332.png
# Epoch [33/300], loss_g: 5.8243, loss_d: 0.0678, real_score: 0.9633, fake_score: 0.0268
# Saving flower-0333.png
# Epoch [34/300], loss_g: 8.6300, loss_d: 0.0813, real_score: 0.9315, fake_score: 0.0009
# Saving flower-0334.png
# Epoch [35/300], loss_g: 5.3353, loss_d: 0.0236, real_score: 0.9933, fake_score: 0.0164
# Saving flower-0335.png
# Epoch [36/300], loss_g: 6.3532, loss_d: 0.2566, real_score: 0.7967, fake_score: 0.0005
# Saving flower-0336.png
# Epoch [37/300], loss_g: 5.1853, loss_d: 0.0140, real_score: 0.9911, fake_score: 0.0048
# Saving flower-0337.png
# Epoch [38/300], loss_g: 5.2261, loss_d: 0.0236, real_score: 0.9879, fake_score: 0.0111
# Saving flower-0338.png
# Epoch [39/300], loss_g: 7.4289, loss_d: 0.1827, real_score: 0.9413, fake_score: 0.0627
# Saving flower-0339.png
# Epoch [40/300], loss_g: 6.7900, loss_d: 0.0036, real_score: 0.9981, fake_score: 0.0016
# Saving flower-0340.png
# Epoch [41/300], loss_g: 8.3372, loss_d: 0.2604, real_score: 0.9853, fake_score: 0.1843
# Saving flower-0341.png
# Epoch [42/300], loss_g: 6.0004, loss_d: 0.0459, real_score: 0.9859, fake_score: 0.0299
# Saving flower-0342.png
# Epoch [43/300], loss_g: 7.6883, loss_d: 0.0075, real_score: 0.9940, fake_score: 0.0014
# Saving flower-0343.png
# Epoch [44/300], loss_g: 9.0739, loss_d: 0.0159, real_score: 0.9846, fake_score: 0.0002
# Saving flower-0344.png
# Epoch [45/300], loss_g: 6.4334, loss_d: 0.0650, real_score: 0.9970, fake_score: 0.0571
# Saving flower-0345.png
# Epoch [46/300], loss_g: 8.6024, loss_d: 0.0975, real_score: 0.9829, fake_score: 0.0696
# Saving flower-0346.png
# Epoch [47/300], loss_g: 13.0490, loss_d: 0.0722, real_score: 0.9348, fake_score: 0.0000
# Saving flower-0347.png
# Epoch [48/300], loss_g: 3.4152, loss_d: 0.2490, real_score: 0.8585, fake_score: 0.0327
# Saving flower-0348.png
# Epoch [49/300], loss_g: 6.7469, loss_d: 0.0307, real_score: 0.9745, fake_score: 0.0035
# Saving flower-0349.png
# Epoch [50/300], loss_g: 5.6153, loss_d: 0.0354, real_score: 0.9823, fake_score: 0.0168
# Saving flower-0350.png
# Epoch [51/300], loss_g: 5.7319, loss_d: 0.0408, real_score: 0.9891, fake_score: 0.0277
# Saving flower-0351.png
# Epoch [52/300], loss_g: 12.0131, loss_d: 0.0795, real_score: 0.9296, fake_score: 0.0000
# Saving flower-0352.png
# Epoch [53/300], loss_g: 5.1989, loss_d: 0.0507, real_score: 0.9613, fake_score: 0.0091
# Saving flower-0353.png
# Epoch [54/300], loss_g: 11.6970, loss_d: 0.0299, real_score: 0.9731, fake_score: 0.0013
# Saving flower-0354.png
# Epoch [55/300], loss_g: 5.2989, loss_d: 0.1048, real_score: 0.9594, fake_score: 0.0559
# Saving flower-0355.png
# Epoch [56/300], loss_g: 6.5656, loss_d: 0.0335, real_score: 0.9766, fake_score: 0.0087
# Saving flower-0356.png
# Epoch [57/300], loss_g: 5.6152, loss_d: 0.0496, real_score: 0.9951, fake_score: 0.0417
# Saving flower-0357.png
# Epoch [58/300], loss_g: 7.2233, loss_d: 0.1323, real_score: 0.9982, fake_score: 0.1079
# Saving flower-0358.png
# Epoch [59/300], loss_g: 5.7351, loss_d: 0.0329, real_score: 0.9903, fake_score: 0.0225
# Saving flower-0359.png
# Epoch [60/300], loss_g: 5.4914, loss_d: 0.0104, real_score: 0.9981, fake_score: 0.0082
# Saving flower-0360.png
# Epoch [61/300], loss_g: 6.2830, loss_d: 0.0188, real_score: 0.9915, fake_score: 0.0098
# Saving flower-0361.png
# Epoch [62/300], loss_g: 13.1896, loss_d: 0.0683, real_score: 0.9397, fake_score: 0.0002
# Saving flower-0362.png
# Epoch [63/300], loss_g: 5.7431, loss_d: 0.0406, real_score: 0.9800, fake_score: 0.0188
# Saving flower-0363.png
# Epoch [64/300], loss_g: 5.6629, loss_d: 0.0441, real_score: 0.9744, fake_score: 0.0169
# Saving flower-0364.png
# Epoch [65/300], loss_g: 4.8456, loss_d: 0.0567, real_score: 0.9772, fake_score: 0.0314
# Saving flower-0365.png
# Epoch [66/300], loss_g: 9.6729, loss_d: 0.0621, real_score: 0.9439, fake_score: 0.0004
# Saving flower-0366.png
# Epoch [67/300], loss_g: 6.9730, loss_d: 0.0836, real_score: 0.9830, fake_score: 0.0616
# Saving flower-0367.png
# Epoch [68/300], loss_g: 6.1595, loss_d: 0.0921, real_score: 0.9954, fake_score: 0.0794
# Saving flower-0368.png
# Epoch [69/300], loss_g: 11.9197, loss_d: 0.8522, real_score: 0.7641, fake_score: 0.0389
# Saving flower-0369.png
# Epoch [70/300], loss_g: 6.0740, loss_d: 0.1141, real_score: 0.9616, fake_score: 0.0613
# Saving flower-0370.png
# Epoch [71/300], loss_g: 5.0094, loss_d: 0.1408, real_score: 0.9173, fake_score: 0.0369
# Saving flower-0371.png
# Epoch [72/300], loss_g: 5.2996, loss_d: 0.0901, real_score: 0.9656, fake_score: 0.0492
# Saving flower-0372.png
# Epoch [73/300], loss_g: 5.0703, loss_d: 0.0761, real_score: 0.9706, fake_score: 0.0414
# Saving flower-0373.png
# Epoch [74/300], loss_g: 4.8772, loss_d: 0.0661, real_score: 0.9664, fake_score: 0.0294
# Saving flower-0374.png
# Epoch [75/300], loss_g: 6.2198, loss_d: 0.0122, real_score: 0.9930, fake_score: 0.0051
# Saving flower-0375.png
# Epoch [76/300], loss_g: 5.8784, loss_d: 0.0296, real_score: 0.9791, fake_score: 0.0073
# Saving flower-0376.png
# Epoch [77/300], loss_g: 11.2763, loss_d: 0.0343, real_score: 0.9680, fake_score: 0.0005
# Saving flower-0377.png
# Epoch [78/300], loss_g: 7.0363, loss_d: 0.1419, real_score: 0.9887, fake_score: 0.1103
# Saving flower-0378.png
# Epoch [79/300], loss_g: 5.2812, loss_d: 0.1181, real_score: 0.9635, fake_score: 0.0695
# Saving flower-0379.png
# Epoch [80/300], loss_g: 5.6232, loss_d: 0.0578, real_score: 0.9852, fake_score: 0.0398
# Saving flower-0380.png
# Epoch [81/300], loss_g: 5.0233, loss_d: 0.0396, real_score: 0.9715, fake_score: 0.0090
# Saving flower-0381.png
# Epoch [82/300], loss_g: 6.8516, loss_d: 0.0235, real_score: 0.9843, fake_score: 0.0071
# Saving flower-0382.png
# Epoch [83/300], loss_g: 7.5311, loss_d: 0.0236, real_score: 0.9779, fake_score: 0.0006
# Saving flower-0383.png
# Epoch [84/300], loss_g: 6.6085, loss_d: 0.0407, real_score: 0.9947, fake_score: 0.0339
# Saving flower-0384.png
# Epoch [85/300], loss_g: 12.4740, loss_d: 0.0057, real_score: 0.9944, fake_score: 0.0001
# Saving flower-0385.png
# Epoch [86/300], loss_g: 5.9436, loss_d: 0.0105, real_score: 0.9959, fake_score: 0.0063
# Saving flower-0386.png
# Epoch [87/300], loss_g: 5.6122, loss_d: 0.0179, real_score: 0.9945, fake_score: 0.0119
# Saving flower-0387.png
# Epoch [88/300], loss_g: 6.9683, loss_d: 0.0087, real_score: 0.9934, fake_score: 0.0021
# Saving flower-0388.png
# Epoch [89/300], loss_g: 6.7706, loss_d: 0.0269, real_score: 0.9952, fake_score: 0.0212
# Saving flower-0389.png
# Epoch [90/300], loss_g: 5.2832, loss_d: 0.0622, real_score: 0.9480, fake_score: 0.0058
# Saving flower-0390.png
# Epoch [91/300], loss_g: 9.4743, loss_d: 0.0128, real_score: 0.9881, fake_score: 0.0002
# Saving flower-0391.png
# Epoch [92/300], loss_g: 10.2492, loss_d: 0.2097, real_score: 0.8952, fake_score: 0.0153
# Saving flower-0392.png
# Epoch [93/300], loss_g: 4.3419, loss_d: 0.0394, real_score: 0.9769, fake_score: 0.0117
# Saving flower-0393.png
# Epoch [94/300], loss_g: 5.1444, loss_d: 0.0869, real_score: 0.9567, fake_score: 0.0368
# Saving flower-0394.png
# Epoch [95/300], loss_g: 4.9681, loss_d: 0.0820, real_score: 0.9586, fake_score: 0.0326
# Saving flower-0395.png
# Epoch [96/300], loss_g: 6.0518, loss_d: 0.0584, real_score: 0.9559, fake_score: 0.0115
# Saving flower-0396.png
# Epoch [97/300], loss_g: 5.9493, loss_d: 0.0331, real_score: 0.9854, fake_score: 0.0165
# Saving flower-0397.png
# Epoch [98/300], loss_g: 5.8548, loss_d: 0.0477, real_score: 0.9687, fake_score: 0.0143
# Saving flower-0398.png
# Epoch [99/300], loss_g: 6.3074, loss_d: 0.0696, real_score: 0.9766, fake_score: 0.0422
# Saving flower-0399.png
# Epoch [100/300], loss_g: 5.9107, loss_d: 0.0669, real_score: 0.9814, fake_score: 0.0441
# Saving flower-0400.png
# Epoch [101/300], loss_g: 6.7516, loss_d: 0.0181, real_score: 0.9923, fake_score: 0.0101
# Saving flower-0401.png
# Epoch [102/300], loss_g: 5.4711, loss_d: 0.0619, real_score: 0.9847, fake_score: 0.0420
# Saving flower-0402.png
# Epoch [103/300], loss_g: 5.4944, loss_d: 0.0526, real_score: 0.9550, fake_score: 0.0037
# Saving flower-0403.png
# Epoch [104/300], loss_g: 6.8608, loss_d: 0.0465, real_score: 0.9975, fake_score: 0.0378
# Saving flower-0404.png
# Epoch [105/300], loss_g: 8.2886, loss_d: 0.5939, real_score: 0.9215, fake_score: 0.1385
# Saving flower-0405.png
# Epoch [106/300], loss_g: 12.9264, loss_d: 0.7009, real_score: 0.9823, fake_score: 0.3758
# Saving flower-0406.png
# Epoch [107/300], loss_g: 5.4479, loss_d: 0.0739, real_score: 0.9467, fake_score: 0.0110
# Saving flower-0407.png
# Epoch [108/300], loss_g: 8.8949, loss_d: 0.2240, real_score: 0.9942, fake_score: 0.1272
# Saving flower-0408.png
# Epoch [109/300], loss_g: 17.1852, loss_d: 0.8062, real_score: 0.9966, fake_score: 0.4443
# Saving flower-0409.png
# Epoch [110/300], loss_g: 4.8866, loss_d: 0.1250, real_score: 0.9190, fake_score: 0.0271
# Saving flower-0410.png
# Epoch [111/300], loss_g: 4.3385, loss_d: 0.1797, real_score: 0.8955, fake_score: 0.0178
# Saving flower-0411.png
# Epoch [112/300], loss_g: 3.8772, loss_d: 0.0810, real_score: 0.9482, fake_score: 0.0231
# Saving flower-0412.png
# Epoch [113/300], loss_g: 5.3051, loss_d: 0.0539, real_score: 0.9863, fake_score: 0.0371
# Saving flower-0413.png
# Epoch [114/300], loss_g: 7.1373, loss_d: 0.1054, real_score: 0.9846, fake_score: 0.0769
# Saving flower-0414.png
# Epoch [115/300], loss_g: 6.0764, loss_d: 0.0165, real_score: 0.9926, fake_score: 0.0089
# Saving flower-0415.png
# Epoch [116/300], loss_g: 5.4919, loss_d: 0.0333, real_score: 0.9951, fake_score: 0.0268
# Saving flower-0416.png
# Epoch [117/300], loss_g: 7.3124, loss_d: 0.0414, real_score: 0.9956, fake_score: 0.0333
# Saving flower-0417.png
# Epoch [118/300], loss_g: 6.1633, loss_d: 0.0455, real_score: 0.9679, fake_score: 0.0110
# Saving flower-0418.png
# Epoch [119/300], loss_g: 5.1911, loss_d: 0.0811, real_score: 0.9697, fake_score: 0.0462
# Saving flower-0419.png
# Epoch [120/300], loss_g: 8.4554, loss_d: 0.0216, real_score: 0.9815, fake_score: 0.0023
# Saving flower-0420.png
# Epoch [121/300], loss_g: 5.6647, loss_d: 0.0426, real_score: 0.9955, fake_score: 0.0346
# Saving flower-0421.png
# Epoch [122/300], loss_g: 11.8065, loss_d: 1.3335, real_score: 0.9992, fake_score: 0.4763
# Saving flower-0422.png
# Epoch [123/300], loss_g: 4.7620, loss_d: 0.0759, real_score: 0.9720, fake_score: 0.0438
# Saving flower-0423.png
# Epoch [124/300], loss_g: 7.5577, loss_d: 0.0638, real_score: 0.9483, fake_score: 0.0059
# Saving flower-0424.png
# Epoch [125/300], loss_g: 5.4619, loss_d: 0.0365, real_score: 0.9890, fake_score: 0.0235
# Saving flower-0425.png
# Epoch [126/300], loss_g: 6.2313, loss_d: 0.0917, real_score: 0.9766, fake_score: 0.0602
# Saving flower-0426.png
# Epoch [127/300], loss_g: 5.1524, loss_d: 0.0341, real_score: 0.9885, fake_score: 0.0215
# Saving flower-0427.png
# Epoch [128/300], loss_g: 6.7803, loss_d: 0.0189, real_score: 0.9837, fake_score: 0.0022
# Saving flower-0428.png
# Epoch [129/300], loss_g: 7.1375, loss_d: 0.0075, real_score: 0.9968, fake_score: 0.0043
# Saving flower-0429.png
# Epoch [130/300], loss_g: 7.7159, loss_d: 0.0376, real_score: 0.9703, fake_score: 0.0026
# Saving flower-0430.png
# Epoch [131/300], loss_g: 11.8804, loss_d: 0.0245, real_score: 0.9776, fake_score: 0.0000
# Saving flower-0431.png
# Epoch [132/300], loss_g: 5.3691, loss_d: 0.0209, real_score: 0.9953, fake_score: 0.0157
# Saving flower-0432.png
# Epoch [133/300], loss_g: 6.6030, loss_d: 0.0698, real_score: 0.9947, fake_score: 0.0594
# Saving flower-0433.png
# Epoch [134/300], loss_g: 11.7517, loss_d: 0.0321, real_score: 0.9698, fake_score: 0.0000
# Saving flower-0434.png
# Epoch [135/300], loss_g: 9.0266, loss_d: 0.0034, real_score: 0.9968, fake_score: 0.0002
# Saving flower-0435.png
# Epoch [136/300], loss_g: 6.1238, loss_d: 0.0476, real_score: 0.9732, fake_score: 0.0185
# Saving flower-0436.png
# Epoch [137/300], loss_g: 10.2732, loss_d: 0.3760, real_score: 0.7823, fake_score: 0.0005
# Saving flower-0437.png
# Epoch [138/300], loss_g: 10.6598, loss_d: 0.3878, real_score: 0.9812, fake_score: 0.2327
# Saving flower-0438.png
# Epoch [139/300], loss_g: 12.7562, loss_d: 0.7928, real_score: 0.9986, fake_score: 0.4178
# Saving flower-0439.png
# Epoch [140/300], loss_g: 6.1234, loss_d: 0.1094, real_score: 0.9301, fake_score: 0.0067
# Saving flower-0440.png
# Epoch [141/300], loss_g: 8.2318, loss_d: 0.0162, real_score: 0.9867, fake_score: 0.0024
# Saving flower-0441.png
# Epoch [142/300], loss_g: 5.4704, loss_d: 0.0265, real_score: 0.9896, fake_score: 0.0153
# Saving flower-0442.png
# Epoch [143/300], loss_g: 6.9633, loss_d: 0.0531, real_score: 0.9977, fake_score: 0.0441
# Saving flower-0443.png
# Epoch [144/300], loss_g: 5.8161, loss_d: 0.0091, real_score: 0.9982, fake_score: 0.0070
# Saving flower-0444.png
# Epoch [145/300], loss_g: 9.1447, loss_d: 0.0523, real_score: 0.9535, fake_score: 0.0001
# Saving flower-0445.png
# Epoch [146/300], loss_g: 7.7292, loss_d: 0.0472, real_score: 0.9594, fake_score: 0.0005
# Saving flower-0446.png
# Epoch [147/300], loss_g: 10.7723, loss_d: 0.1945, real_score: 0.9985, fake_score: 0.1503
# Saving flower-0447.png
# Epoch [148/300], loss_g: 11.0307, loss_d: 0.8740, real_score: 0.9987, fake_score: 0.3968
# Saving flower-0448.png
# Epoch [149/300], loss_g: 6.4319, loss_d: 0.0905, real_score: 0.9958, fake_score: 0.0744
# Saving flower-0449.png
# Epoch [150/300], loss_g: 6.1033, loss_d: 0.0256, real_score: 0.9910, fake_score: 0.0137
# Saving flower-0450.png
# Epoch [151/300], loss_g: 9.1289, loss_d: 0.1122, real_score: 0.9056, fake_score: 0.0004
# Saving flower-0451.png
# Epoch [152/300], loss_g: 6.4722, loss_d: 0.0103, real_score: 0.9977, fake_score: 0.0079
# Saving flower-0452.png
# Epoch [153/300], loss_g: 6.0766, loss_d: 0.1692, real_score: 0.9277, fake_score: 0.0637
# Saving flower-0453.png
# Epoch [154/300], loss_g: 4.8765, loss_d: 0.0759, real_score: 0.9620, fake_score: 0.0329
# Saving flower-0454.png
# Epoch [155/300], loss_g: 6.1577, loss_d: 0.0643, real_score: 0.9621, fake_score: 0.0210
# Saving flower-0455.png
# Epoch [156/300], loss_g: 4.7536, loss_d: 0.0734, real_score: 0.9620, fake_score: 0.0301
# Saving flower-0456.png
# Epoch [157/300], loss_g: 4.7869, loss_d: 0.0512, real_score: 0.9807, fake_score: 0.0299
# Saving flower-0457.png
# Epoch [158/300], loss_g: 4.0335, loss_d: 0.1190, real_score: 0.9132, fake_score: 0.0219
# Saving flower-0458.png
# Epoch [159/300], loss_g: 5.4567, loss_d: 0.0443, real_score: 0.9911, fake_score: 0.0334
# Saving flower-0459.png
# Epoch [160/300], loss_g: 4.7281, loss_d: 0.0426, real_score: 0.9761, fake_score: 0.0174
# Saving flower-0460.png
# Epoch [161/300], loss_g: 6.0503, loss_d: 0.0564, real_score: 0.9766, fake_score: 0.0302
# Saving flower-0461.png
# Epoch [162/300], loss_g: 5.3953, loss_d: 0.0294, real_score: 0.9890, fake_score: 0.0171
# Saving flower-0462.png
# Epoch [163/300], loss_g: 5.8082, loss_d: 0.0245, real_score: 0.9979, fake_score: 0.0217
# Saving flower-0463.png
# Epoch [164/300], loss_g: 8.5329, loss_d: 0.4115, real_score: 0.7471, fake_score: 0.0034
# Saving flower-0464.png
# Epoch [165/300], loss_g: 5.9398, loss_d: 0.0450, real_score: 0.9855, fake_score: 0.0280
# Saving flower-0465.png
# Epoch [166/300], loss_g: 4.8120, loss_d: 0.0775, real_score: 0.9604, fake_score: 0.0317
# Saving flower-0466.png
# Epoch [167/300], loss_g: 5.8988, loss_d: 0.0809, real_score: 0.9933, fake_score: 0.0654
# Saving flower-0467.png
# Epoch [168/300], loss_g: 8.6252, loss_d: 0.6088, real_score: 0.9896, fake_score: 0.2690
# Saving flower-0468.png
# Epoch [169/300], loss_g: 4.7778, loss_d: 0.1314, real_score: 0.9015, fake_score: 0.0152
# Saving flower-0469.png
# Epoch [170/300], loss_g: 4.7862, loss_d: 0.0881, real_score: 0.9540, fake_score: 0.0359
# Saving flower-0470.png
# Epoch [171/300], loss_g: 4.9496, loss_d: 0.0884, real_score: 0.9470, fake_score: 0.0292
# Saving flower-0471.png
# Epoch [172/300], loss_g: 5.6396, loss_d: 0.0357, real_score: 0.9813, fake_score: 0.0162
# Saving flower-0472.png
# Epoch [173/300], loss_g: 7.1378, loss_d: 0.1621, real_score: 0.9807, fake_score: 0.1230
# Saving flower-0473.png
# Epoch [174/300], loss_g: 6.6933, loss_d: 0.0236, real_score: 0.9842, fake_score: 0.0072
# Saving flower-0474.png
# Epoch [175/300], loss_g: 6.8355, loss_d: 0.0115, real_score: 0.9903, fake_score: 0.0016
# Saving flower-0475.png
# Epoch [176/300], loss_g: 6.0642, loss_d: 0.1265, real_score: 0.9826, fake_score: 0.0865
# Saving flower-0476.png
# Epoch [177/300], loss_g: 5.6133, loss_d: 0.0496, real_score: 0.9794, fake_score: 0.0234
# Saving flower-0477.png
# Epoch [178/300], loss_g: 10.1623, loss_d: 0.2787, real_score: 0.9876, fake_score: 0.1827
# Saving flower-0478.png
# Epoch [179/300], loss_g: 5.5220, loss_d: 0.0181, real_score: 0.9941, fake_score: 0.0119
# Saving flower-0479.png
# Epoch [180/300], loss_g: 7.2607, loss_d: 0.0147, real_score: 0.9869, fake_score: 0.0013
# Saving flower-0480.png
# Epoch [181/300], loss_g: 6.5128, loss_d: 0.0278, real_score: 0.9848, fake_score: 0.0115
# Saving flower-0481.png
# Epoch [182/300], loss_g: 3.7789, loss_d: 0.1131, real_score: 0.9324, fake_score: 0.0302
# Saving flower-0482.png
# Epoch [183/300], loss_g: 4.0654, loss_d: 0.1157, real_score: 0.9465, fake_score: 0.0502
# Saving flower-0483.png
# Epoch [184/300], loss_g: 4.5418, loss_d: 0.0514, real_score: 0.9830, fake_score: 0.0315
# Saving flower-0484.png
# Epoch [185/300], loss_g: 6.2244, loss_d: 0.0602, real_score: 0.9911, fake_score: 0.0463
# Saving flower-0485.png
# Epoch [186/300], loss_g: 4.6234, loss_d: 0.0303, real_score: 0.9840, fake_score: 0.0136
# Saving flower-0486.png
# Epoch [187/300], loss_g: 4.1966, loss_d: 0.1228, real_score: 0.8989, fake_score: 0.0044
# Saving flower-0487.png
# Epoch [188/300], loss_g: 6.6737, loss_d: 0.0169, real_score: 0.9973, fake_score: 0.0134
# Saving flower-0488.png
# Epoch [189/300], loss_g: 7.3143, loss_d: 0.0786, real_score: 0.9953, fake_score: 0.0585
# Saving flower-0489.png
# Epoch [190/300], loss_g: 6.9671, loss_d: 0.0173, real_score: 0.9851, fake_score: 0.0020
# Saving flower-0490.png
# Epoch [191/300], loss_g: 6.5594, loss_d: 0.0481, real_score: 0.9987, fake_score: 0.0427
# Saving flower-0491.png
# Epoch [192/300], loss_g: 5.6836, loss_d: 0.0169, real_score: 0.9949, fake_score: 0.0115
# Saving flower-0492.png
# Epoch [193/300], loss_g: 6.7812, loss_d: 0.0235, real_score: 0.9796, fake_score: 0.0025
# Saving flower-0493.png
# Epoch [194/300], loss_g: 20.6215, loss_d: 10.7861, real_score: 1.0000, fake_score: 0.9136
# Saving flower-0494.png
# Epoch [195/300], loss_g: 6.6003, loss_d: 0.0703, real_score: 0.9844, fake_score: 0.0495
# Saving flower-0495.png
# Epoch [196/300], loss_g: 6.6789, loss_d: 0.1066, real_score: 0.9956, fake_score: 0.0888
# Saving flower-0496.png
# Epoch [197/300], loss_g: 6.8555, loss_d: 0.0905, real_score: 0.9931, fake_score: 0.0727
# Saving flower-0497.png
# Epoch [198/300], loss_g: 5.8502, loss_d: 0.0373, real_score: 0.9881, fake_score: 0.0237
# Saving flower-0498.png
# Epoch [199/300], loss_g: 6.0654, loss_d: 0.0267, real_score: 0.9809, fake_score: 0.0069
# Saving flower-0499.png
# Epoch [200/300], loss_g: 5.7843, loss_d: 0.0593, real_score: 0.9946, fake_score: 0.0479
# Saving flower-0500.png
# Epoch [201/300], loss_g: 5.6042, loss_d: 0.0689, real_score: 0.9453, fake_score: 0.0100
# Saving flower-0501.png
# Epoch [202/300], loss_g: 6.0098, loss_d: 0.0563, real_score: 0.9862, fake_score: 0.0399
# Saving flower-0502.png
# Epoch [203/300], loss_g: 5.8438, loss_d: 0.0611, real_score: 0.9823, fake_score: 0.0405
# Saving flower-0503.png
# Epoch [204/300], loss_g: 6.7733, loss_d: 0.0075, real_score: 0.9983, fake_score: 0.0056
# Saving flower-0504.png
# Epoch [205/300], loss_g: 12.6078, loss_d: 0.4576, real_score: 0.9999, fake_score: 0.2601
# Saving flower-0505.png
# Epoch [206/300], loss_g: 5.9970, loss_d: 0.2748, real_score: 0.8121, fake_score: 0.0001
# Saving flower-0506.png
# Epoch [207/300], loss_g: 6.4929, loss_d: 0.0150, real_score: 0.9880, fake_score: 0.0027
# Saving flower-0507.png
# Epoch [208/300], loss_g: 10.0252, loss_d: 0.1215, real_score: 0.9036, fake_score: 0.0008
# Saving flower-0508.png
# Epoch [209/300], loss_g: 7.9608, loss_d: 0.1812, real_score: 0.9624, fake_score: 0.0581
# Saving flower-0509.png
# Epoch [210/300], loss_g: 8.3344, loss_d: 0.0377, real_score: 0.9730, fake_score: 0.0024
# Saving flower-0510.png
# Epoch [211/300], loss_g: 6.8208, loss_d: 0.0090, real_score: 0.9944, fake_score: 0.0033
# Saving flower-0511.png
# Epoch [212/300], loss_g: 5.1984, loss_d: 0.0436, real_score: 0.9717, fake_score: 0.0134
# Saving flower-0512.png
# Epoch [213/300], loss_g: 8.4442, loss_d: 0.0095, real_score: 0.9913, fake_score: 0.0007
# Saving flower-0513.png
# Epoch [214/300], loss_g: 7.6468, loss_d: 0.0184, real_score: 0.9838, fake_score: 0.0003
# Saving flower-0514.png
# Epoch [215/300], loss_g: 9.4360, loss_d: 0.0066, real_score: 0.9937, fake_score: 0.0002
# Saving flower-0515.png
# Epoch [216/300], loss_g: 4.0075, loss_d: 0.0406, real_score: 0.9739, fake_score: 0.0132
# Saving flower-0516.png
# Epoch [217/300], loss_g: 6.6854, loss_d: 0.0054, real_score: 0.9975, fake_score: 0.0029
# Saving flower-0517.png
# Epoch [218/300], loss_g: 7.8422, loss_d: 0.0049, real_score: 0.9961, fake_score: 0.0009
# Saving flower-0518.png
# Epoch [219/300], loss_g: 8.4316, loss_d: 0.0111, real_score: 0.9903, fake_score: 0.0011
# Saving flower-0519.png
# Epoch [220/300], loss_g: 25.6062, loss_d: 3.3858, real_score: 1.0000, fake_score: 0.7222
# Saving flower-0520.png
# Epoch [221/300], loss_g: 7.7008, loss_d: 0.0805, real_score: 0.9803, fake_score: 0.0521
# Saving flower-0521.png
# Epoch [222/300], loss_g: 5.9082, loss_d: 0.0799, real_score: 0.9566, fake_score: 0.0265
# Saving flower-0522.png
# Epoch [223/300], loss_g: 6.2608, loss_d: 0.1021, real_score: 0.9979, fake_score: 0.0815
# Saving flower-0523.png
# Epoch [224/300], loss_g: 5.7136, loss_d: 0.0729, real_score: 0.9697, fake_score: 0.0359
# Saving flower-0524.png
# Epoch [225/300], loss_g: 5.9375, loss_d: 0.0663, real_score: 0.9678, fake_score: 0.0290
# Saving flower-0525.png
# Epoch [226/300], loss_g: 5.5172, loss_d: 0.0391, real_score: 0.9757, fake_score: 0.0136
# Saving flower-0526.png
# Epoch [227/300], loss_g: 5.2405, loss_d: 0.0523, real_score: 0.9686, fake_score: 0.0182
# Saving flower-0527.png
# Epoch [228/300], loss_g: 5.7646, loss_d: 0.0314, real_score: 0.9802, fake_score: 0.0106
# Saving flower-0528.png
# Epoch [229/300], loss_g: 5.8878, loss_d: 0.2147, real_score: 0.8285, fake_score: 0.0009
# Saving flower-0529.png
# Epoch [230/300], loss_g: 5.4580, loss_d: 0.0163, real_score: 0.9945, fake_score: 0.0104
# Saving flower-0530.png
# Epoch [231/300], loss_g: 5.8473, loss_d: 0.0228, real_score: 0.9912, fake_score: 0.0133
# Saving flower-0531.png
# Epoch [232/300], loss_g: 5.9538, loss_d: 0.0302, real_score: 0.9808, fake_score: 0.0103
# Saving flower-0532.png
# Epoch [233/300], loss_g: 7.3164, loss_d: 0.0497, real_score: 0.9975, fake_score: 0.0435
# Saving flower-0533.png
# Epoch [234/300], loss_g: 8.3348, loss_d: 0.0527, real_score: 0.9519, fake_score: 0.0006
# Saving flower-0534.png
# Epoch [235/300], loss_g: 8.8418, loss_d: 0.0057, real_score: 0.9952, fake_score: 0.0009
# Saving flower-0535.png
# Epoch [236/300], loss_g: 8.4309, loss_d: 0.0056, real_score: 0.9969, fake_score: 0.0024
# Saving flower-0536.png
# Epoch [237/300], loss_g: 4.7238, loss_d: 0.6792, real_score: 0.6568, fake_score: 0.0020
# Saving flower-0537.png
# Epoch [238/300], loss_g: 5.9237, loss_d: 0.1013, real_score: 0.9554, fake_score: 0.0474
# Saving flower-0538.png
# Epoch [239/300], loss_g: 5.2739, loss_d: 0.0707, real_score: 0.9654, fake_score: 0.0320
# Saving flower-0539.png
# Epoch [240/300], loss_g: 4.1188, loss_d: 0.0854, real_score: 0.9539, fake_score: 0.0310
# Saving flower-0540.png
# Epoch [241/300], loss_g: 4.9383, loss_d: 0.0742, real_score: 0.9463, fake_score: 0.0153
# Saving flower-0541.png
# Epoch [242/300], loss_g: 5.5642, loss_d: 0.0190, real_score: 0.9929, fake_score: 0.0116
# Saving flower-0542.png
# Epoch [243/300], loss_g: 5.8039, loss_d: 0.0609, real_score: 0.9598, fake_score: 0.0180
# Saving flower-0543.png
# Epoch [244/300], loss_g: 5.2931, loss_d: 0.0396, real_score: 0.9833, fake_score: 0.0213
# Saving flower-0544.png
# Epoch [245/300], loss_g: 4.4776, loss_d: 0.0546, real_score: 0.9742, fake_score: 0.0268
# Saving flower-0545.png
# Epoch [246/300], loss_g: 4.6012, loss_d: 0.0273, real_score: 0.9865, fake_score: 0.0133
# Saving flower-0546.png
# Epoch [247/300], loss_g: 7.3750, loss_d: 0.0100, real_score: 0.9920, fake_score: 0.0019
# Saving flower-0547.png
# Epoch [248/300], loss_g: 7.2606, loss_d: 0.0117, real_score: 0.9902, fake_score: 0.0018
# Saving flower-0548.png
# Epoch [249/300], loss_g: 9.5547, loss_d: 0.0321, real_score: 0.9695, fake_score: 0.0003
# Saving flower-0549.png
# Epoch [250/300], loss_g: 6.3974, loss_d: 0.0394, real_score: 0.9773, fake_score: 0.0152
# Saving flower-0550.png
# Epoch [251/300], loss_g: 7.3955, loss_d: 0.0070, real_score: 0.9977, fake_score: 0.0046
# Saving flower-0551.png
# Epoch [252/300], loss_g: 6.7931, loss_d: 0.0430, real_score: 0.9973, fake_score: 0.0370
# Saving flower-0552.png
# Epoch [253/300], loss_g: 6.9906, loss_d: 0.0094, real_score: 0.9953, fake_score: 0.0046
# Saving flower-0553.png
# Epoch [254/300], loss_g: 10.6136, loss_d: 0.5486, real_score: 0.9888, fake_score: 0.2637
# Saving flower-0554.png
# Epoch [255/300], loss_g: 8.2723, loss_d: 0.2594, real_score: 0.9708, fake_score: 0.1436
# Saving flower-0555.png
# Epoch [256/300], loss_g: 4.4501, loss_d: 0.1963, real_score: 0.9023, fake_score: 0.0566
# Saving flower-0556.png
# Epoch [257/300], loss_g: 6.1016, loss_d: 0.1525, real_score: 0.9624, fake_score: 0.0848
# Saving flower-0557.png
# Epoch [258/300], loss_g: 7.5696, loss_d: 0.1447, real_score: 0.9906, fake_score: 0.1131
# Saving flower-0558.png
# Epoch [259/300], loss_g: 6.4752, loss_d: 0.0862, real_score: 0.9774, fake_score: 0.0557
# Saving flower-0559.png
# Epoch [260/300], loss_g: 4.2725, loss_d: 0.1311, real_score: 0.9140, fake_score: 0.0319
# Saving flower-0560.png
# Epoch [261/300], loss_g: 5.3897, loss_d: 0.0706, real_score: 0.9686, fake_score: 0.0345
# Saving flower-0561.png
# Epoch [262/300], loss_g: 5.1332, loss_d: 0.0663, real_score: 0.9441, fake_score: 0.0055
# Saving flower-0562.png
# Epoch [263/300], loss_g: 6.0904, loss_d: 0.0396, real_score: 0.9645, fake_score: 0.0028
# Saving flower-0563.png
# Epoch [264/300], loss_g: 5.3780, loss_d: 0.0359, real_score: 0.9917, fake_score: 0.0263
# Saving flower-0564.png
# Epoch [265/300], loss_g: 7.0996, loss_d: 0.0345, real_score: 0.9682, fake_score: 0.0011
# Saving flower-0565.png
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_33483/421978362.py in <module>
# ----> 1 history = fit(epochs, lr,start_idx=301)
#
# /tmp/ipykernel_33483/2845868582.py in fit(epochs, lr, start_idx)
#      15         for real_images, _ in (train_dl):
#      16             # Train discriminator
# ---> 17             loss_d, real_score, fake_score = train_discriminator(real_images, opt_d)
#      18             # Train generator
#      19             loss_g = train_generator(opt_g)
#
# /tmp/ipykernel_33483/2100296819.py in train_discriminator(real_images, opt_d)
#      23     loss.backward()
#      24     opt_d.step()
# ---> 25     return loss.item(), real_score, fake_score
#
# KeyboardInterrupt:

# %%
torch.save(generator.state_dict(), 'G_flowers.pth')
torch.save(discriminator.state_dict(), 'D_flowers.pth')

# %%
import cv2
import os

frame = cv2.imread("flower_gen1/flower-0527.png")
height, width, layers = frame.shape


#insering frames into video
video = cv2.VideoWriter("./flower_gan2.avi", 0,10, (width, height)) 
files = os.listdir("flower_gen1")
files.sort()
for i in files: 
   video.write(cv2.imread("flower_gen1/"+i)) 
   print(i)
# Out:
# flower-0000.png
# flower-0001.png
# flower-0002.png
# flower-0003.png
# flower-0004.png
# flower-0005.png
# flower-0006.png
# flower-0007.png
# flower-0008.png
# flower-0009.png
# flower-0010.png
# flower-0011.png
# flower-0012.png
# flower-0013.png
# flower-0014.png
# flower-0015.png
# flower-0016.png
# flower-0017.png
# flower-0018.png
# flower-0019.png
# flower-0020.png
# flower-0021.png
# flower-0022.png
# flower-0023.png
# flower-0024.png
# flower-0025.png
# flower-0026.png
# flower-0027.png
# flower-0028.png
# flower-0029.png
# flower-0030.png
# flower-0031.png
# flower-0032.png
# flower-0033.png
# flower-0034.png
# flower-0035.png
# flower-0036.png
# flower-0037.png
# flower-0038.png
# flower-0039.png
# flower-0040.png
# flower-0041.png
# flower-0042.png
# flower-0043.png
# flower-0044.png
# flower-0045.png
# flower-0046.png
# flower-0047.png
# flower-0048.png
# flower-0049.png
# flower-0050.png
# flower-0051.png
# flower-0052.png
# flower-0053.png
# flower-0054.png
# flower-0055.png
# flower-0056.png
# flower-0057.png
# flower-0058.png
# flower-0059.png
# flower-0060.png
# flower-0061.png
# flower-0062.png
# flower-0063.png
# flower-0064.png
# flower-0065.png
# flower-0066.png
# flower-0067.png
# flower-0068.png
# flower-0069.png
# flower-0070.png
# flower-0071.png
# flower-0072.png
# flower-0073.png
# flower-0074.png
# flower-0075.png
# flower-0076.png
# flower-0077.png
# flower-0078.png
# flower-0079.png
# flower-0080.png
# flower-0081.png
# flower-0082.png
# flower-0083.png
# flower-0084.png
# flower-0085.png
# flower-0086.png
# flower-0087.png
# flower-0088.png
# flower-0089.png
# flower-0090.png
# flower-0091.png
# flower-0092.png
# flower-0093.png
# flower-0094.png
# flower-0095.png
# flower-0096.png
# flower-0097.png
# flower-0098.png
# flower-0099.png
# flower-0100.png
# flower-0101.png
# flower-0102.png
# flower-0103.png
# flower-0104.png
# flower-0105.png
# flower-0106.png
# flower-0107.png
# flower-0108.png
# flower-0109.png
# flower-0110.png
# flower-0111.png
# flower-0112.png
# flower-0113.png
# flower-0114.png
# flower-0115.png
# flower-0116.png
# flower-0117.png
# flower-0118.png
# flower-0119.png
# flower-0120.png
# flower-0121.png
# flower-0122.png
# flower-0123.png
# flower-0124.png
# flower-0125.png
# flower-0126.png
# flower-0127.png
# flower-0128.png
# flower-0129.png
# flower-0130.png
# flower-0131.png
# flower-0132.png
# flower-0133.png
# flower-0134.png
# flower-0135.png
# flower-0136.png
# flower-0137.png
# flower-0138.png
# flower-0139.png
# flower-0140.png
# flower-0141.png
# flower-0142.png
# flower-0143.png
# flower-0144.png
# flower-0145.png
# flower-0146.png
# flower-0147.png
# flower-0148.png
# flower-0149.png
# flower-0150.png
# flower-0151.png
# flower-0152.png
# flower-0153.png
# flower-0154.png
# flower-0155.png
# flower-0156.png
# flower-0157.png
# flower-0158.png
# flower-0159.png
# flower-0160.png
# flower-0161.png
# flower-0162.png
# flower-0163.png
# flower-0164.png
# flower-0165.png
# flower-0166.png
# flower-0167.png
# flower-0168.png
# flower-0169.png
# flower-0170.png
# flower-0171.png
# flower-0172.png
# flower-0173.png
# flower-0174.png
# flower-0175.png
# flower-0176.png
# flower-0177.png
# flower-0178.png
# flower-0179.png
# flower-0180.png
# flower-0181.png
# flower-0182.png
# flower-0183.png
# flower-0184.png
# flower-0185.png
# flower-0186.png
# flower-0187.png
# flower-0188.png
# flower-0189.png
# flower-0190.png
# flower-0191.png
# flower-0192.png
# flower-0193.png
# flower-0194.png
# flower-0195.png
# flower-0196.png
# flower-0197.png
# flower-0198.png
# flower-0199.png
# flower-0200.png
# flower-0201.png
# flower-0202.png
# flower-0203.png
# flower-0204.png
# flower-0205.png
# flower-0206.png
# flower-0207.png
# flower-0208.png
# flower-0209.png
# flower-0210.png
# flower-0211.png
# flower-0212.png
# flower-0213.png
# flower-0214.png
# flower-0215.png
# flower-0216.png
# flower-0217.png
# flower-0218.png
# flower-0219.png
# flower-0220.png
# flower-0221.png
# flower-0222.png
# flower-0223.png
# flower-0224.png
# flower-0225.png
# flower-0226.png
# flower-0227.png
# flower-0228.png
# flower-0229.png
# flower-0230.png
# flower-0231.png
# flower-0232.png
# flower-0233.png
# flower-0234.png
# flower-0235.png
# flower-0236.png
# flower-0237.png
# flower-0238.png
# flower-0239.png
# flower-0240.png
# flower-0241.png
# flower-0242.png
# flower-0243.png
# flower-0244.png
# flower-0245.png
# flower-0246.png
# flower-0247.png
# flower-0248.png
# flower-0249.png
# flower-0250.png
# flower-0251.png
# flower-0252.png
# flower-0253.png
# flower-0254.png
# flower-0255.png
# flower-0256.png
# flower-0257.png
# flower-0258.png
# flower-0259.png
# flower-0260.png
# flower-0261.png
# flower-0262.png
# flower-0263.png
# flower-0264.png
# flower-0265.png
# flower-0266.png
# flower-0267.png
# flower-0268.png
# flower-0269.png
# flower-0270.png
# flower-0271.png
# flower-0272.png
# flower-0273.png
# flower-0274.png
# flower-0275.png
# flower-0276.png
# flower-0277.png
# flower-0278.png
# flower-0279.png
# flower-0280.png
# flower-0281.png
# flower-0282.png
# flower-0283.png
# flower-0284.png
# flower-0285.png
# flower-0286.png
# flower-0287.png
# flower-0288.png
# flower-0289.png
# flower-0290.png
# flower-0291.png
# flower-0292.png
# flower-0293.png
# flower-0294.png
# flower-0295.png
# flower-0296.png
# flower-0297.png
# flower-0298.png
# flower-0299.png
# flower-0300.png
# flower-0301.png
# flower-0302.png
# flower-0303.png
# flower-0304.png
# flower-0305.png
# flower-0306.png
# flower-0307.png
# flower-0308.png
# flower-0309.png
# flower-0310.png
# flower-0311.png
# flower-0312.png
# flower-0313.png
# flower-0314.png
# flower-0315.png
# flower-0316.png
# flower-0317.png
# flower-0318.png
# flower-0319.png
# flower-0320.png
# flower-0321.png
# flower-0322.png
# flower-0323.png
# flower-0324.png
# flower-0325.png
# flower-0326.png
# flower-0327.png
# flower-0328.png
# flower-0329.png
# flower-0330.png
# flower-0331.png
# flower-0332.png
# flower-0333.png
# flower-0334.png
# flower-0335.png
# flower-0336.png
# flower-0337.png
# flower-0338.png
# flower-0339.png
# flower-0340.png
# flower-0341.png
# flower-0342.png
# flower-0343.png
# flower-0344.png
# flower-0345.png
# flower-0346.png
# flower-0347.png
# flower-0348.png
# flower-0349.png
# flower-0350.png
# flower-0351.png
# flower-0352.png
# flower-0353.png
# flower-0354.png
# flower-0355.png
# flower-0356.png
# flower-0357.png
# flower-0358.png
# flower-0359.png
# flower-0360.png
# flower-0361.png
# flower-0362.png
# flower-0363.png
# flower-0364.png
# flower-0365.png
# flower-0366.png
# flower-0367.png
# flower-0368.png
# flower-0369.png
# flower-0370.png
# flower-0371.png
# flower-0372.png
# flower-0373.png
# flower-0374.png
# flower-0375.png
# flower-0376.png
# flower-0377.png
# flower-0378.png
# flower-0379.png
# flower-0380.png
# flower-0381.png
# flower-0382.png
# flower-0383.png
# flower-0384.png
# flower-0385.png
# flower-0386.png
# flower-0387.png
# flower-0388.png
# flower-0389.png
# flower-0390.png
# flower-0391.png
# flower-0392.png
# flower-0393.png
# flower-0394.png
# flower-0395.png
# flower-0396.png
# flower-0397.png
# flower-0398.png
# flower-0399.png
# flower-0400.png
# flower-0401.png
# flower-0402.png
# flower-0403.png
# flower-0404.png
# flower-0405.png
# flower-0406.png
# flower-0407.png
# flower-0408.png
# flower-0409.png
# flower-0410.png
# flower-0411.png
# flower-0412.png
# flower-0413.png
# flower-0414.png
# flower-0415.png
# flower-0416.png
# flower-0417.png
# flower-0418.png
# flower-0419.png
# flower-0420.png
# flower-0421.png
# flower-0422.png
# flower-0423.png
# flower-0424.png
# flower-0425.png
# flower-0426.png
# flower-0427.png
# flower-0428.png
# flower-0429.png
# flower-0430.png
# flower-0431.png
# flower-0432.png
# flower-0433.png
# flower-0434.png
# flower-0435.png
# flower-0436.png
# flower-0437.png
# flower-0438.png
# flower-0439.png
# flower-0440.png
# flower-0441.png
# flower-0442.png
# flower-0443.png
# flower-0444.png
# flower-0445.png
# flower-0446.png
# flower-0447.png
# flower-0448.png
# flower-0449.png
# flower-0450.png
# flower-0451.png
# flower-0452.png
# flower-0453.png
# flower-0454.png
# flower-0455.png
# flower-0456.png
# flower-0457.png
# flower-0458.png
# flower-0459.png
# flower-0460.png
# flower-0461.png
# flower-0462.png
# flower-0463.png
# flower-0464.png
# flower-0465.png
# flower-0466.png
# flower-0467.png
# flower-0468.png
# flower-0469.png
# flower-0470.png
# flower-0471.png
# flower-0472.png
# flower-0473.png
# flower-0474.png
# flower-0475.png
# flower-0476.png
# flower-0477.png
# flower-0478.png
# flower-0479.png
# flower-0480.png
# flower-0481.png
# flower-0482.png
# flower-0483.png
# flower-0484.png
# flower-0485.png
# flower-0486.png
# flower-0487.png
# flower-0488.png
# flower-0489.png
# flower-0490.png
# flower-0491.png
# flower-0492.png
# flower-0493.png
# flower-0494.png
# flower-0495.png
# flower-0496.png
# flower-0497.png
# flower-0498.png
# flower-0499.png
# flower-0500.png
# flower-0501.png
# flower-0502.png
# flower-0503.png
# flower-0504.png
# flower-0505.png
# flower-0506.png
# flower-0507.png
# flower-0508.png
# flower-0509.png
# flower-0510.png
# flower-0511.png
# flower-0512.png
# flower-0513.png
# flower-0514.png
# flower-0515.png
# flower-0516.png
# flower-0517.png
# flower-0518.png
# flower-0519.png
# flower-0520.png
# flower-0521.png
# flower-0522.png
# flower-0523.png
# flower-0524.png
# flower-0525.png
# flower-0526.png
# flower-0527.png
# flower-0528.png
# flower-0529.png
# flower-0530.png
# flower-0531.png
# flower-0532.png
# flower-0533.png
# flower-0534.png
# flower-0535.png
# flower-0536.png
# flower-0537.png
# flower-0538.png
# flower-0539.png
# flower-0540.png
# flower-0541.png
# flower-0542.png
# flower-0543.png
# flower-0544.png
# flower-0545.png
# flower-0546.png
# flower-0547.png
# flower-0548.png
# flower-0549.png
# flower-0550.png
# flower-0551.png
# flower-0552.png
# flower-0553.png
# flower-0554.png
# flower-0555.png
# flower-0556.png
# flower-0557.png
# flower-0558.png
# flower-0559.png
# flower-0560.png
# flower-0561.png
# flower-0562.png
# flower-0563.png
# flower-0564.png
# flower-0565.png

# %%
# print(os.listdir("simp_generation_1"))
